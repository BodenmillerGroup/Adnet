# %% [markdown]
# # Compare Readouts vs bpR2
#
# Author: Vito Zanotelli
#
# The goal of this analysis is to compare the results of using bpR2 vs Spearman/Pearson correlation vs DREMI (Conditional density-based analysis of T cell signaling in single-cell data, Science 2014). The cutoff is chosen to be the 99percentile of the negative controls.
#
# The bpR2/Spearman/Pearson were calculated using the Adnet script.
# The DREMI value was calculated using the reference matlab GUI implementation from the DREMI paper (from https://www.c2b2.columbia.edu/danapeerlab/html/dremi.html) modified to write out the results as a .csv file.
#
# This script reproduces supplemenatary figure 11.

# %%
from  __future__ import division
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import os
import numpy as np
from matplotlib_venn import venn3, venn3_circles
import bokeh.plotting as bplt
import bokeh.models as bmod
import bokeh as bk
bk.io.output_notebook()
# %matplotlib inline
# Out:
#     <script type="text/javascript">
#
#       (function(global) {
#         function now() {
#           return new Date();
#         }
#
#         if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#           window._bokeh_onload_callbacks = [];
#         }
#
#         function run_callbacks() {
#           window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#           delete window._bokeh_onload_callbacks
#           console.info("Bokeh: all callbacks have finished");
#         }
#
#         function load_libs(js_urls, callback) {
#           window._bokeh_onload_callbacks.push(callback);
#           if (window._bokeh_is_loading > 0) {
#             console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#             return null;
#           }
#           if (js_urls == null || js_urls.length === 0) {
#             run_callbacks();
#             return null;
#           }
#           console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#           window._bokeh_is_loading = js_urls.length;
#           for (var i = 0; i < js_urls.length; i++) {
#             var url = js_urls[i];
#             var s = document.createElement('script');
#             s.src = url;
#             s.async = false;
#             s.onreadystatechange = s.onload = function() {
#               window._bokeh_is_loading--;
#               if (window._bokeh_is_loading === 0) {
#                 console.log("Bokeh: all BokehJS libraries loaded");
#                 run_callbacks()
#               }
#             };
#             s.onerror = function() {
#               console.warn("failed to load library " + url);
#             };
#             console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#             document.getElementsByTagName("head")[0].appendChild(s);
#           }
#         };var js_urls = ['https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.js', 'https://cdn.pydata.org/bokeh/release/bokeh-compiler-0.11.0.min.js'];
#
#         var inline_js = [
#           function(Bokeh) {
#             Bokeh.set_log_level("info");
#           },
#           function(Bokeh) {
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-0.11.0.min.css");
#             console.log("Bokeh: injecting CSS: https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#             Bokeh.embed.inject_css("https://cdn.pydata.org/bokeh/release/bokeh-widgets-0.11.0.min.css");
#           }
#         ];
#
#         function run_inline_js() {
#           for (var i = 0; i < inline_js.length; i++) {
#             inline_js[i](window.Bokeh);
#           }
#         }
#
#         if (window._bokeh_is_loading === 0) {
#           console.log("Bokeh: BokehJS loaded, going straight to plotting");
#           run_inline_js();
#         } else {
#           load_libs(js_urls, function() {
#             console.log("Bokeh: BokehJS plotting callback run at", now());
#             run_inline_js();
#           });
#         }
#       }(this));
#     </script>
#     <div>
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span>BokehJS successfully loaded.</span>
#     </div>

# %% [markdown]
# Set the file paths

# %%
# the bin_dat pickle file, outputed by the adnet analysis script
bin_dat_fn = '/mnt/imls-bod/XiaoKangL/EGF transfection/plots/nbin10_2.5perc_bpr2_median_25_final/t_bindat'
# exported from the matlab dremi gui
dremi_fn = '/home/vitoz/imls-bod/XiaoKangL/EGF transfection/benchmark/20160314_dremi_values_all_overexpressions.csv'
# a dictionary with the old and new names
name_dict = '/home/vitoz/imls-bod/XiaoKangL/EGF transfection/name_dict.csv'
out_folder = '/home/vitoz/Data/Analysis/XKL'
neg_ctrl_names = ['empty-1','empty-2','GFP-FLAG-1','GFP-FLAG-2']
# neg_ctrl_names = ['empty-1','empty-2']

# %% [markdown]
# For this analysis the non signaling cell cycle markers were excluded as they show quite strong multimodal relationships also in the GFP-FLAG controls. As DREMI is sensistive for such patterns, a unfair high cuttoff would be chosen for DREMI, making it look worse than it is.
# An alternative is to not use the GFP-FLAG controls and not to exclude any markers (commented out lines). In this case DREMI recovers a lot of cell-cycle interactions but misses out on many relevant ones.

# %%
# markers that are excluded from the analysis 
excluded_names = ['cleaved PARP-cleaved caspase3', 'cyclin B1', 'p-4EBP1', 'p-HH3', 'p-RB', 'beads']
#excluded_names =[]

# %% [markdown]
# Load the binned data file

# %%
bin_dat = pd.read_pickle(bin_dat_fn)
bin_dat.index.get_level_values('target').unique()
# Out:
# array(['Beta-catenin', 'E-cadherin', 'beads',
#        'cleaved PARP-cleaved caspase3', 'cyclin B1', 'p-4EBP1', 'p-AKT',
#        'p-AMPKalpha', 'p-BTK', 'p-CREB', 'p-ERK1-2', 'p-FAK',
#        'p-GSK3-Beta', 'p-HH3', 'p-JNK', 'p-MAPKAPK2', 'p-MARCKS',
#        'p-MEK1-2', 'p-MKK3', 'p-MKK3-6', 'p-NfkB', 'p-PDPK1', 'p-PLCg2',
#        'p-RB', 'p-S6', 'p-SHP2', 'p-SMAD1-5', 'p-SMAD2-3', 'p-STAT1',
#        'p-STAT3', 'p-STAT5', 'p-mTOR', 'p-p38', 'p-p70S6K', 'p-p90RSK'], dtype=object)

# %% [markdown]
# Prepare the name dict

# %%
name_dict = pd.read_csv(name_dict)
name_dict = {row['old']: row['new'] for idx, row in name_dict.iterrows()}

# %% [markdown]
# Read the DREMI data

# %%
dat_dremi = pd.read_csv(dremi_fn, sep=',',index_col=False)
dat_dremi.head()
# Out:
#   origin  target  \
# 0    gfp     idu
# 1    gfp   pcreb
# 2    gfp  pstat5
# 3    gfp   pshp2
# 4    gfp    pfak
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150406/gated/BaseFileName_B10_cell_SRC-GFP EGF 60min.fcs  \
# 0                                            0.12445
# 1                                            0.29583
# 2                                            0.50454
# 3                                            0.42297
# 4                                            0.50240
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150406/gated/BaseFileName_B11_cell_MAP2K6-GFP EGF 60min.fcs  \
# 0                                           0.001861
# 1                                           0.220030
# 2                                           0.221740
# 3                                           0.153250
# 4                                           0.127230
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150406/gated/BaseFileName_B2_cell_SRC-GFP EGF 0min.fcs  \
# 0                                            0.17874
# 1                                            0.19061
# 2                                            0.43672
# 3                                            0.36183
# 4                                            0.46869
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150406/gated/BaseFileName_B3_cell_MAP2K6-GFP EGF 0min.fcs  \
# 0                                           0.000000
# 1                                           0.084494
# 2                                           0.217850
# 3                                           0.057021
# 4                                           0.170330
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150406/gated/BaseFileName_B4_cell_SRC-GFP EGF 5min.fcs  \
# 0                                            0.11858
# 1                                            0.18983
# 2                                            0.45457
# 3                                            0.28165
# 4                                            0.41797
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150406/gated/BaseFileName_B5_cell_MAP2K6-GFP EGF 5min.fcs  \
# 0                                           0.000000
# 1                                           0.192050
# 2                                           0.171900
# 3                                           0.010023
# 4                                           0.177040
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150406/gated/BaseFileName_B6_cell_SRC-GFP EGF 15min.fcs  \
# 0                                           0.095233
# 1                                           0.261740
# 2                                           0.559990
# 3                                           0.408160
# 4                                           0.579020
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150406/gated/BaseFileName_B7_cell_MAP2K6-GFP EGF 15min.fcs  \
# 0                                           0.000000
# 1                                           0.213340
# 2                                           0.223150
# 3                                           0.062089
# 4                                           0.107260
#
#                                                    ...                                                   \
# 0                                                  ...
# 1                                                  ...
# 2                                                  ...
# 3                                                  ...
# 4                                                  ...
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150605/gated/BaseFileName_G10_cell_MAP2K7-GFP EGF 60min.fcs  \
# 0                                           0.032370
# 1                                           0.129090
# 2                                           0.237980
# 3                                           0.002691
# 4                                           0.094818
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150605/gated/BaseFileName_G11_cell_Empty-GFP EGF 60min.fcs  \
# 0                                            0.22224
# 1                                            0.22609
# 2                                            0.15508
# 3                                            0.15556
# 4                                            0.13604
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150605/gated/BaseFileName_G2_cell_MAP2K7-GFP EGF 0min.fcs  \
# 0                                           0.144480
# 1                                           0.108570
# 2                                           0.121040
# 3                                           0.004671
# 4                                           0.061195
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150605/gated/BaseFileName_G3_cell_Empty EGF 0min.fcs  \
# 0                                           0.102980
# 1                                           0.252460
# 2                                           0.119500
# 3                                           0.098055
# 4                                           0.094007
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150605/gated/BaseFileName_G4_cell_MAP2K7-GFP EGF 5min.fcs  \
# 0                                           0.137430
# 1                                           0.143060
# 2                                           0.018499
# 3                                           0.018680
# 4                                           0.035332
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150605/gated/BaseFileName_G5_cell_Empty-GFP EGF 5min.fcs  \
# 0                                           0.232220
# 1                                           0.224680
# 2                                           0.078073
# 3                                           0.069710
# 4                                           0.095992
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150605/gated/BaseFileName_G6_cell_MAP2K7-GFP EGF 15min.fcs  \
# 0                                           0.180840
# 1                                           0.119310
# 2                                           0.060820
# 3                                           0.036441
# 4                                           0.086016
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150605/gated/BaseFileName_G7_cell_Empty-GFP EGF 15min.fcs  \
# 0                                           0.078002
# 1                                           0.191620
# 2                                           0.054951
# 3                                           0.121500
# 4                                           0.106280
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150605/gated/BaseFileName_G8_cell_MAP2K7-GFP EGF 30min.fcs  \
# 0                                           0.009091
# 1                                           0.130410
# 2                                           0.119430
# 3                                           0.012267
# 4                                           0.064840
#
#    /mnt/imls-bod/Xiao-Kang/EGF transfection/20150605/gated/BaseFileName_G9_cell_Empty-GFP EGF 30min.fcs
# 0                                           0.132090
# 1                                           0.278740
# 2                                           0.104330
# 3                                           0.089511
# 4                                           0.090380
#
# [5 rows x 362 columns]

# %% [markdown]
# make the name dict compatible with the DREMI names (only alphanumeric, lower case)

# %%
name_dict_dremi = dict((filter(str.isalnum, oldname.lower()), nicename) for oldname, nicename in name_dict.iteritems())

# %%
dat_dremi['target'] = dat_dremi['target'].map(lambda x: name_dict_dremi[x])

# %% [markdown]
# Merge the dremi data with the bpr2 data

# %%
dat_dremi_stacked = dat_dremi.copy()
dat_dremi_stacked['origin'] = dat_dremi_stacked['origin'].map(lambda x: x.upper())
dat_dremi_stacked['origin'].map(lambda x: x.upper())
dat_dremi_stacked = dat_dremi_stacked.set_index(['origin','target'])

dat_dremi_stacked =  pd.DataFrame(dat_dremi_stacked.stack(), columns=['dremi'])
dat_dremi_stacked.index.names = ['origin', 'target', 'filename']

# extract experiment and row-col from the filename

get_experiment = lambda x: x.split('/')[5]
get_rowcol = lambda x: x.split('/')[5]
dat_dremi_stacked['experiment'] = [x.split('/')[5] for x in dat_dremi_stacked.index.get_level_values('filename')]
dat_dremi_stacked['row_col'] = [x.split('_')[1] for x in dat_dremi_stacked.index.get_level_values('filename')]

dat_dremi_stacked = dat_dremi_stacked.reset_index('filename', drop=True)
dat_dremi_stacked = dat_dremi_stacked.reset_index()

t_dat = bin_dat.reset_index()
t_dat = t_dat[bin_dat.index.names]
t_dat.columns = t_dat.columns.get_level_values(0)
dat_dremi_stacked = pd.merge(t_dat, dat_dremi_stacked, how='outer')

# due to the way the merging was performed, both bindat and dat_dremi are now aligned

dat_dremi_stacked = dat_dremi_stacked.dropna(subset=['marker'])
bin_dat[('stats', 'dremi')] = dat_dremi_stacked['dremi'].tolist()

# %% [markdown]
# Calculate the dremi median over the replicates

# %%
bin_dat[('stats', 'dremi_median')] = bin_dat[('stats', 'dremi')].groupby(level=['marker', 'origin', 'target', 'timepoint','perturbation']).transform(np.median)

# %% [markdown]
# Prepare the negative control filter

# %%
bin_dat = bin_dat.loc[bin_dat.index.get_level_values('target').isin(excluded_names) == False, :]
neg_mark_fil = bin_dat.index.get_level_values('marker').isin(neg_ctrl_names)

# %% [markdown]
# Filter out the non wanted markers

# %% [markdown]
# ### Start the comparison

# %%
bin_dat.loc[neg_mark_fil == False].index.get_level_values('marker').unique()
# Out:
# array(['AKT1', 'CRAF', 'GSK3B', 'MAP2K1', 'MAP2K6', 'MAPK1', 'MAPK14',
#        'PDPK1', 'RPS6KA1', 'SRC', 'MAP2K7', 'BRAF', 'HRAS', 'KRAS',
#        'MAP3K5', 'MAP8', 'PIK3CA', 'PTPN11', 'RPS6', 'RPS6KB1'], dtype=object)

# %% [markdown]
# Calculate the cutoffs using the negative control for dremi, bpr2 and spearman

# %%
bins = np.arange(0,1,0.025)

bin_dat.loc[neg_mark_fil == False, ('stats', 'dremi_median')].hist(normed=1,bins=bins)
bin_dat.loc[neg_mark_fil, ('stats', 'dremi_median')].hist(normed=1, alpha=0.4,bins=bins)

maxneg_dremi = bin_dat.loc[neg_mark_fil, ('stats', 'dremi_median')].max()
maxneg_dremi_99 = np.percentile(bin_dat.loc[neg_mark_fil, ('stats', 'dremi_median')].dropna(),99,)
maxneg_dremi_90 = np.percentile(bin_dat.loc[neg_mark_fil, ('stats', 'dremi_median')].dropna(),90,)
print(bin_dat.loc[neg_mark_fil == False, ('stats', 'dremi_median')].max())
print(bin_dat.loc[neg_mark_fil, ('stats', 'dremi_median')].max())

print(maxneg_dremi)
print(np.sum(bin_dat.loc[neg_mark_fil == False, ('stats', 'dremi_median')] > maxneg_dremi)/3)
print(maxneg_dremi_99)
print(np.sum(bin_dat.loc[neg_mark_fil == False, ('stats', 'dremi_median')] > maxneg_dremi_99)/3)
# Out:
# 0.60886
# 0.26063
# 0.26063
# 215.0
# 0.2370849
# 285.0

# %%
bin_dat['stats']
bins = np.arange(0,1,0.025)

bin_dat.loc[neg_mark_fil == False, ('stats', 'median_mean_var_ratio')].hist(normed=1,bins=bins)
bin_dat.loc[neg_mark_fil, ('stats', 'median_mean_var_ratio')].hist(normed=1, alpha=0.4,bins=bins)

maxneg_bp = bin_dat.loc[neg_mark_fil, ('stats', 'median_mean_var_ratio')].max()
maxneg_bp_99 = np.percentile(bin_dat.loc[neg_mark_fil, ('stats', 'median_mean_var_ratio')].dropna(),99)
maxneg_bp_90 = np.percentile(bin_dat.loc[neg_mark_fil, ('stats', 'median_mean_var_ratio')].dropna(),90)

print(bin_dat.loc[neg_mark_fil == False, ('stats', 'median_mean_var_ratio')].max())
print(bin_dat.loc[neg_mark_fil, ('stats', 'median_mean_var_ratio')].max())

print(maxneg_bp)
print(np.sum(bin_dat.loc[neg_mark_fil == False, ('stats', 'median_mean_var_ratio')] > maxneg_bp)/3)
print(maxneg_bp_99)
print(np.sum(bin_dat.loc[neg_mark_fil == False, ('stats', 'median_mean_var_ratio')] > maxneg_bp_99)/3)
# Out:
# 0.60043307503
# 0.107025850812
# 0.107025850812
# 362.0
# 0.0816725058111
# 531.0

# %%
maxneg_bp_99
# Out:
# 0.081672505811096571

# %%
bin_dat['stats']
bins = np.arange(0,1,0.025)

bin_dat.loc[neg_mark_fil == False, ('stats', 'median_abs_corr_spearman_overall')].hist(normed=1,bins=bins)
bin_dat.loc[neg_mark_fil, ('stats', 'median_abs_corr_spearman_overall')].hist(normed=1, alpha=0.4,bins=bins)

maxneg_sp = bin_dat.loc[neg_mark_fil, ('stats', 'median_abs_corr_spearman_overall')].max()
maxneg_sp_99 = np.percentile(bin_dat.loc[neg_mark_fil, ('stats', 'median_abs_corr_spearman_overall')].dropna(),99,)
maxneg_sp_90 = np.percentile(bin_dat.loc[neg_mark_fil, ('stats', 'median_abs_corr_spearman_overall')].dropna(),90,)
print(bin_dat.loc[neg_mark_fil == False, ('stats', 'median_abs_corr_spearman_overall')].max())
print(bin_dat.loc[neg_mark_fil, ('stats', 'median_abs_corr_spearman_overall')].max())

print(maxneg_sp)
print(np.sum(bin_dat.loc[neg_mark_fil == False, ('stats', 'median_abs_corr_spearman_overall')] > maxneg_sp)/3)
print(maxneg_bp_99)
print(np.sum(bin_dat.loc[neg_mark_fil == False, ('stats', 'median_abs_corr_spearman_overall')] > maxneg_sp_99)/3)
# Out:
# 0.883761073375
# 0.302999170874
# 0.302999170874
# 458.0
# 0.0816725058111
# 524.0

# %%
bin_dat['stats']
bins = np.arange(0,1,0.025)

bin_dat.loc[neg_mark_fil == False, ('stats', 'median_abs_corr_pearson_overall')].hist(normed=1,bins=bins)
bin_dat.loc[neg_mark_fil, ('stats', 'median_abs_corr_pearson_overall')].hist(normed=1, alpha=0.4,bins=bins)

maxneg_pc = bin_dat.loc[neg_mark_fil, ('stats', 'median_abs_corr_pearson_overall')].max()
maxneg_pc_99 = np.percentile(bin_dat.loc[neg_mark_fil, ('stats', 'median_abs_corr_pearson_overall')].dropna(),99,)
maxneg_pc_90 = np.percentile(bin_dat.loc[neg_mark_fil, ('stats', 'median_abs_corr_pearson_overall')].dropna(),90,)
print(bin_dat.loc[neg_mark_fil == False, ('stats', 'median_abs_corr_pearson_overall')].max())
print(bin_dat.loc[neg_mark_fil, ('stats', 'median_abs_corr_pearson_overall')].max())

print(maxneg_pc)
print(np.sum(bin_dat.loc[neg_mark_fil == False, ('stats', 'median_abs_corr_pearson_overall')] > maxneg_sp)/3)
print(maxneg_pc_99)
print(np.sum(bin_dat.loc[neg_mark_fil == False, ('stats', 'median_abs_corr_pearson_overall')] > maxneg_sp_99)/3)
# Out:
# 0.902864409007
# 0.352638354144
# 0.352638354144
# 454.0
# 0.305756640261
# 530.0

# %%
#fil = bin_dat[('stats', 'dremi_median')] > 0.24
#fildat = bin_dat.loc[(fil) & (neg_mark_fil)]
#hits_dremi_GFP = set('_'.join([m, t, str(tp)]) for m, t, tp in
#             zip(fildat.reset_index()['marker'],fildat.reset_index()['target'],fildat.reset_index()['timepoint']))
#hits_dremi_GFP

# %% [markdown]
# Compare the overlap of hits between

# %%
fil = bin_dat[('stats', 'dremi_median')] > maxneg_dremi_99
fildat = bin_dat.loc[(fil) & (neg_mark_fil == False)]

hits_dremi = set('_'.join([m, t, str(tp)]) for m, t, tp in
             zip(fildat.reset_index()['marker'],fildat.reset_index()['target'],fildat.reset_index()['timepoint']))

fil = bin_dat[('stats', 'median_mean_var_ratio')] > maxneg_bp_99
fildat = bin_dat.loc[(fil) & (neg_mark_fil == False)]

hits_bp = set('_'.join([m, t, str(tp)]) for m, t, tp in
             zip(fildat.reset_index()['marker'],fildat.reset_index()['target'],fildat.reset_index()['timepoint']))

fil = bin_dat[('stats', 'median_abs_corr_spearman_overall')] > maxneg_sp_99

fildat = bin_dat.loc[(fil) & (neg_mark_fil == False)]

hits_sp = set('_'.join([m, t, str(tp)]) for m, t, tp in
             zip(fildat.reset_index()['marker'],fildat.reset_index()['target'],fildat.reset_index()['timepoint']))

fil = bin_dat[('stats', 'median_abs_corr_pearson_overall')] > maxneg_pc_99

fildat = bin_dat.loc[(fil) & (neg_mark_fil == False)]

hits_pc = set('_'.join([m, t, str(tp)]) for m, t, tp in
             zip(fildat.reset_index()['marker'],fildat.reset_index()['target'],fildat.reset_index()['timepoint']))

# %% [markdown]
# Look at the different hits as a venn diagramm

# %%
venn3([hits_bp,hits_sp,hits_dremi],set_labels=['bp-R2', 'Spearman', 'DREMI'])
# Out:
# <matplotlib_venn._common.VennDiagram instance at 0x7f8080c80c68>

# %% [markdown]
# -> This is  the supplementary figure 11 a)

# %%
venn3([hits_bp,hits_pc,hits_dremi],set_labels=['bp-R2', 'Pearson', 'DREMI'])
# Out:
# <matplotlib_venn._common.VennDiagram instance at 0x7f8080b57998>

# %% [markdown]
# ## Look how exactly the hits differ

# %%
hits_bp
# Out:
# {'AKT1_Beta-catenin_0',
#  'AKT1_Beta-catenin_15',
#  'AKT1_Beta-catenin_30',
#  'AKT1_Beta-catenin_5',
#  'AKT1_Beta-catenin_60',
#  'AKT1_p-AKT_0',
#  'AKT1_p-AKT_15',
#  'AKT1_p-AKT_30',
#  'AKT1_p-AKT_5',
#  'AKT1_p-AKT_60',
#  'AKT1_p-BTK_0',
#  'AKT1_p-BTK_15',
#  'AKT1_p-BTK_30',
#  'AKT1_p-BTK_5',
#  'AKT1_p-BTK_60',
#  'AKT1_p-GSK3-Beta_0',
#  'AKT1_p-GSK3-Beta_15',
#  'AKT1_p-GSK3-Beta_30',
#  'AKT1_p-GSK3-Beta_5',
#  'AKT1_p-GSK3-Beta_60',
#  'AKT1_p-MKK3-6_0',
#  'AKT1_p-MKK3-6_15',
#  'AKT1_p-MKK3-6_30',
#  'AKT1_p-MKK3-6_5',
#  'AKT1_p-MKK3-6_60',
#  'AKT1_p-PDPK1_0',
#  'AKT1_p-PDPK1_30',
#  'AKT1_p-PDPK1_5',
#  'AKT1_p-PDPK1_60',
#  'AKT1_p-SMAD1-5_0',
#  'AKT1_p-SMAD1-5_30',
#  'AKT1_p-SMAD1-5_5',
#  'AKT1_p-SMAD1-5_60',
#  'AKT1_p-SMAD2-3_0',
#  'AKT1_p-SMAD2-3_15',
#  'AKT1_p-SMAD2-3_30',
#  'AKT1_p-SMAD2-3_5',
#  'AKT1_p-SMAD2-3_60',
#  'AKT1_p-p70S6K_0',
#  'AKT1_p-p70S6K_15',
#  'AKT1_p-p70S6K_30',
#  'AKT1_p-p70S6K_5',
#  'AKT1_p-p70S6K_60',
#  'BRAF_p-JNK_15',
#  'BRAF_p-JNK_30',
#  'BRAF_p-JNK_60',
#  'BRAF_p-MKK3-6_0',
#  'BRAF_p-MKK3-6_15',
#  'BRAF_p-MKK3-6_30',
#  'BRAF_p-MKK3-6_5',
#  'BRAF_p-MKK3-6_60',
#  'BRAF_p-S6_0',
#  'BRAF_p-S6_15',
#  'BRAF_p-SMAD1-5_0',
#  'BRAF_p-SMAD1-5_15',
#  'BRAF_p-SMAD1-5_30',
#  'BRAF_p-SMAD1-5_5',
#  'BRAF_p-p38_15',
#  'BRAF_p-p38_60',
#  'CRAF_p-ERK1-2_5',
#  'CRAF_p-JNK_0',
#  'CRAF_p-JNK_5',
#  'CRAF_p-PLCg2_5',
#  'CRAF_p-S6_15',
#  'CRAF_p-S6_30',
#  'CRAF_p-S6_60',
#  'CRAF_p-SMAD1-5_30',
#  'CRAF_p-p90RSK_0',
#  'CRAF_p-p90RSK_5',
#  'GSK3B_Beta-catenin_0',
#  'GSK3B_Beta-catenin_15',
#  'GSK3B_Beta-catenin_30',
#  'GSK3B_Beta-catenin_5',
#  'GSK3B_Beta-catenin_60',
#  'GSK3B_E-cadherin_15',
#  'GSK3B_E-cadherin_5',
#  'GSK3B_p-BTK_15',
#  'GSK3B_p-BTK_30',
#  'GSK3B_p-BTK_5',
#  'GSK3B_p-BTK_60',
#  'GSK3B_p-FAK_0',
#  'GSK3B_p-FAK_15',
#  'GSK3B_p-FAK_5',
#  'GSK3B_p-FAK_60',
#  'GSK3B_p-GSK3-Beta_0',
#  'GSK3B_p-GSK3-Beta_15',
#  'GSK3B_p-GSK3-Beta_30',
#  'GSK3B_p-GSK3-Beta_5',
#  'GSK3B_p-GSK3-Beta_60',
#  'GSK3B_p-MEK1-2_0',
#  'GSK3B_p-MEK1-2_30',
#  'GSK3B_p-MEK1-2_5',
#  'GSK3B_p-MEK1-2_60',
#  'GSK3B_p-MKK3_0',
#  'GSK3B_p-MKK3_15',
#  'GSK3B_p-MKK3_30',
#  'GSK3B_p-MKK3_5',
#  'GSK3B_p-MKK3_60',
#  'GSK3B_p-PDPK1_0',
#  'GSK3B_p-PDPK1_15',
#  'GSK3B_p-PDPK1_30',
#  'GSK3B_p-PDPK1_5',
#  'GSK3B_p-PDPK1_60',
#  'GSK3B_p-S6_15',
#  'GSK3B_p-S6_5',
#  'GSK3B_p-SHP2_0',
#  'GSK3B_p-SHP2_15',
#  'GSK3B_p-SHP2_30',
#  'GSK3B_p-SHP2_5',
#  'GSK3B_p-SHP2_60',
#  'GSK3B_p-STAT1_0',
#  'GSK3B_p-STAT1_15',
#  'GSK3B_p-STAT1_30',
#  'GSK3B_p-STAT1_5',
#  'GSK3B_p-STAT1_60',
#  'GSK3B_p-STAT5_0',
#  'GSK3B_p-STAT5_30',
#  'GSK3B_p-STAT5_5',
#  'GSK3B_p-STAT5_60',
#  'GSK3B_p-p70S6K_0',
#  'GSK3B_p-p70S6K_15',
#  'GSK3B_p-p70S6K_30',
#  'GSK3B_p-p70S6K_5',
#  'GSK3B_p-p70S6K_60',
#  'GSK3B_p-p90RSK_5',
#  'HRAS_p-ERK1-2_60',
#  'HRAS_p-JNK_0',
#  'HRAS_p-JNK_15',
#  'HRAS_p-JNK_30',
#  'HRAS_p-JNK_5',
#  'HRAS_p-JNK_60',
#  'HRAS_p-SMAD1-5_0',
#  'HRAS_p-SMAD1-5_15',
#  'HRAS_p-SMAD1-5_30',
#  'HRAS_p-SMAD1-5_5',
#  'HRAS_p-SMAD1-5_60',
#  'HRAS_p-SMAD2-3_0',
#  'HRAS_p-SMAD2-3_15',
#  'HRAS_p-SMAD2-3_30',
#  'HRAS_p-SMAD2-3_5',
#  'HRAS_p-SMAD2-3_60',
#  'HRAS_p-p38_15',
#  'HRAS_p-p38_30',
#  'HRAS_p-p38_5',
#  'HRAS_p-p90RSK_60',
#  'KRAS_p-ERK1-2_15',
#  'KRAS_p-ERK1-2_30',
#  'KRAS_p-ERK1-2_5',
#  'KRAS_p-MKK3-6_15',
#  'KRAS_p-MKK3-6_30',
#  'KRAS_p-S6_15',
#  'KRAS_p-S6_30',
#  'KRAS_p-S6_60',
#  'KRAS_p-p90RSK_15',
#  'KRAS_p-p90RSK_30',
#  'KRAS_p-p90RSK_5',
#  'MAP2K1_Beta-catenin_0',
#  'MAP2K1_Beta-catenin_5',
#  'MAP2K1_Beta-catenin_60',
#  'MAP2K1_p-BTK_0',
#  'MAP2K1_p-BTK_30',
#  'MAP2K1_p-BTK_60',
#  'MAP2K1_p-ERK1-2_5',
#  'MAP2K1_p-GSK3-Beta_0',
#  'MAP2K1_p-GSK3-Beta_30',
#  'MAP2K1_p-GSK3-Beta_5',
#  'MAP2K1_p-GSK3-Beta_60',
#  'MAP2K1_p-MARCKS_5',
#  'MAP2K1_p-MEK1-2_0',
#  'MAP2K1_p-MEK1-2_15',
#  'MAP2K1_p-MEK1-2_30',
#  'MAP2K1_p-MEK1-2_5',
#  'MAP2K1_p-MEK1-2_60',
#  'MAP2K1_p-MKK3-6_0',
#  'MAP2K1_p-MKK3-6_15',
#  'MAP2K1_p-MKK3-6_30',
#  'MAP2K1_p-MKK3-6_5',
#  'MAP2K1_p-MKK3-6_60',
#  'MAP2K1_p-MKK3_30',
#  'MAP2K1_p-MKK3_5',
#  'MAP2K1_p-MKK3_60',
#  'MAP2K1_p-SMAD1-5_30',
#  'MAP2K1_p-SMAD1-5_60',
#  'MAP2K1_p-SMAD2-3_0',
#  'MAP2K1_p-SMAD2-3_30',
#  'MAP2K1_p-SMAD2-3_5',
#  'MAP2K1_p-SMAD2-3_60',
#  'MAP2K1_p-STAT5_0',
#  'MAP2K1_p-STAT5_15',
#  'MAP2K1_p-STAT5_30',
#  'MAP2K1_p-STAT5_5',
#  'MAP2K1_p-STAT5_60',
#  'MAP2K1_p-p90RSK_15',
#  'MAP2K1_p-p90RSK_5',
#  'MAP2K6_p-ERK1-2_15',
#  'MAP2K6_p-GSK3-Beta_0',
#  'MAP2K6_p-GSK3-Beta_15',
#  'MAP2K6_p-GSK3-Beta_30',
#  'MAP2K6_p-GSK3-Beta_5',
#  'MAP2K6_p-MARCKS_5',
#  'MAP2K6_p-MKK3-6_0',
#  'MAP2K6_p-MKK3-6_15',
#  'MAP2K6_p-MKK3-6_30',
#  'MAP2K6_p-MKK3-6_5',
#  'MAP2K6_p-MKK3-6_60',
#  'MAP2K6_p-MKK3_30',
#  'MAP2K6_p-MKK3_5',
#  'MAP2K6_p-PDPK1_5',
#  'MAP2K6_p-SMAD1-5_15',
#  'MAP2K6_p-SMAD1-5_30',
#  'MAP2K6_p-SMAD1-5_5',
#  'MAP2K6_p-SMAD1-5_60',
#  'MAP2K6_p-STAT1_0',
#  'MAP2K6_p-STAT1_15',
#  'MAP2K6_p-STAT1_30',
#  'MAP2K6_p-STAT1_5',
#  'MAP2K6_p-STAT1_60',
#  'MAP2K6_p-STAT5_0',
#  'MAP2K6_p-STAT5_15',
#  'MAP2K6_p-STAT5_30',
#  'MAP2K6_p-STAT5_5',
#  'MAP2K6_p-STAT5_60',
#  'MAP2K6_p-p38_0',
#  'MAP2K6_p-p38_15',
#  'MAP2K6_p-p38_30',
#  'MAP2K6_p-p38_5',
#  'MAP2K6_p-p38_60',
#  'MAP2K7_p-ERK1-2_30',
#  'MAP2K7_p-JNK_60',
#  'MAP2K7_p-SMAD1-5_0',
#  'MAP2K7_p-SMAD1-5_15',
#  'MAP2K7_p-SMAD1-5_5',
#  'MAP2K7_p-SMAD1-5_60',
#  'MAP2K7_p-p90RSK_60',
#  'MAP3K5_Beta-catenin_30',
#  'MAP3K5_p-AMPKalpha_0',
#  'MAP3K5_p-AMPKalpha_15',
#  'MAP3K5_p-AMPKalpha_30',
#  'MAP3K5_p-AMPKalpha_5',
#  'MAP3K5_p-AMPKalpha_60',
#  'MAP3K5_p-BTK_15',
#  'MAP3K5_p-BTK_30',
#  'MAP3K5_p-BTK_5',
#  'MAP3K5_p-BTK_60',
#  'MAP3K5_p-ERK1-2_60',
#  'MAP3K5_p-GSK3-Beta_0',
#  'MAP3K5_p-GSK3-Beta_30',
#  'MAP3K5_p-GSK3-Beta_60',
#  'MAP3K5_p-JNK_0',
#  'MAP3K5_p-JNK_15',
#  'MAP3K5_p-JNK_30',
#  'MAP3K5_p-JNK_5',
#  'MAP3K5_p-JNK_60',
#  'MAP3K5_p-MAPKAPK2_0',
#  'MAP3K5_p-MAPKAPK2_15',
#  'MAP3K5_p-MAPKAPK2_30',
#  'MAP3K5_p-MAPKAPK2_5',
#  'MAP3K5_p-MAPKAPK2_60',
#  'MAP3K5_p-MKK3-6_0',
#  'MAP3K5_p-MKK3-6_15',
#  'MAP3K5_p-MKK3-6_30',
#  'MAP3K5_p-MKK3-6_5',
#  'MAP3K5_p-MKK3-6_60',
#  'MAP3K5_p-MKK3_0',
#  'MAP3K5_p-MKK3_30',
#  'MAP3K5_p-PDPK1_0',
#  'MAP3K5_p-PDPK1_15',
#  'MAP3K5_p-PDPK1_30',
#  'MAP3K5_p-PDPK1_5',
#  'MAP3K5_p-PDPK1_60',
#  'MAP3K5_p-SMAD1-5_0',
#  'MAP3K5_p-SMAD1-5_15',
#  'MAP3K5_p-SMAD1-5_30',
#  'MAP3K5_p-SMAD1-5_5',
#  'MAP3K5_p-SMAD1-5_60',
#  'MAP3K5_p-SMAD2-3_0',
#  'MAP3K5_p-SMAD2-3_15',
#  'MAP3K5_p-SMAD2-3_30',
#  'MAP3K5_p-SMAD2-3_5',
#  'MAP3K5_p-SMAD2-3_60',
#  'MAP3K5_p-STAT1_0',
#  'MAP3K5_p-STAT1_15',
#  'MAP3K5_p-STAT1_30',
#  'MAP3K5_p-STAT1_5',
#  'MAP3K5_p-STAT1_60',
#  'MAP3K5_p-p38_0',
#  'MAP3K5_p-p38_15',
#  'MAP3K5_p-p38_30',
#  'MAP3K5_p-p38_5',
#  'MAP3K5_p-p38_60',
#  'MAP3K5_p-p90RSK_5',
#  'MAP8_p-JNK_0',
#  'MAP8_p-JNK_15',
#  'MAP8_p-JNK_30',
#  'MAP8_p-JNK_5',
#  'MAP8_p-JNK_60',
#  'MAP8_p-MAPKAPK2_0',
#  'MAP8_p-MAPKAPK2_15',
#  'MAP8_p-MAPKAPK2_30',
#  'MAP8_p-MAPKAPK2_5',
#  'MAP8_p-MAPKAPK2_60',
#  'MAP8_p-PDPK1_0',
#  'MAP8_p-PDPK1_30',
#  'MAP8_p-PDPK1_60',
#  'MAP8_p-STAT1_0',
#  'MAP8_p-STAT1_15',
#  'MAP8_p-STAT1_30',
#  'MAP8_p-STAT1_5',
#  'MAP8_p-STAT1_60',
#  'MAP8_p-STAT3_15',
#  'MAP8_p-STAT3_30',
#  'MAP8_p-STAT5_30',
#  'MAP8_p-STAT5_5',
#  'MAP8_p-STAT5_60',
#  'MAP8_p-p38_0',
#  'MAP8_p-p38_30',
#  'MAP8_p-p38_5',
#  'MAP8_p-p38_60',
#  'MAP8_p-p70S6K_0',
#  'MAP8_p-p70S6K_60',
#  'MAPK14_p-ERK1-2_15',
#  'MAPK14_p-p38_0',
#  'MAPK14_p-p38_15',
#  'MAPK14_p-p38_30',
#  'MAPK14_p-p38_5',
#  'MAPK14_p-p38_60',
#  'MAPK14_p-p90RSK_15',
#  'MAPK1_p-ERK1-2_0',
#  'MAPK1_p-ERK1-2_15',
#  'MAPK1_p-ERK1-2_30',
#  'MAPK1_p-ERK1-2_5',
#  'MAPK1_p-ERK1-2_60',
#  'MAPK1_p-JNK_30',
#  'MAPK1_p-JNK_60',
#  'MAPK1_p-MAPKAPK2_15',
#  'MAPK1_p-MAPKAPK2_30',
#  'MAPK1_p-MAPKAPK2_60',
#  'MAPK1_p-SMAD1-5_0',
#  'MAPK1_p-SMAD1-5_5',
#  'MAPK1_p-SMAD1-5_60',
#  'MAPK1_p-SMAD2-3_5',
#  'MAPK1_p-STAT1_30',
#  'MAPK1_p-STAT1_60',
#  'MAPK1_p-p38_0',
#  'MAPK1_p-p38_15',
#  'MAPK1_p-p38_30',
#  'MAPK1_p-p38_60',
#  'MAPK1_p-p70S6K_15',
#  'MAPK1_p-p90RSK_15',
#  'MAPK1_p-p90RSK_5',
#  'PDPK1_p-BTK_0',
#  'PDPK1_p-BTK_15',
#  'PDPK1_p-BTK_30',
#  'PDPK1_p-BTK_5',
#  'PDPK1_p-BTK_60',
#  'PDPK1_p-FAK_0',
#  'PDPK1_p-FAK_15',
#  'PDPK1_p-FAK_30',
#  'PDPK1_p-FAK_5',
#  'PDPK1_p-FAK_60',
#  'PDPK1_p-MAPKAPK2_0',
#  'PDPK1_p-MAPKAPK2_15',
#  'PDPK1_p-MAPKAPK2_30',
#  'PDPK1_p-MAPKAPK2_5',
#  'PDPK1_p-MAPKAPK2_60',
#  'PDPK1_p-MEK1-2_0',
#  'PDPK1_p-MEK1-2_15',
#  'PDPK1_p-MEK1-2_30',
#  'PDPK1_p-MEK1-2_5',
#  'PDPK1_p-MEK1-2_60',
#  'PDPK1_p-MKK3-6_0',
#  'PDPK1_p-MKK3-6_15',
#  'PDPK1_p-MKK3-6_30',
#  'PDPK1_p-MKK3-6_5',
#  'PDPK1_p-MKK3-6_60',
#  'PDPK1_p-PDPK1_0',
#  'PDPK1_p-PDPK1_15',
#  'PDPK1_p-PDPK1_30',
#  'PDPK1_p-PDPK1_5',
#  'PDPK1_p-PDPK1_60',
#  'PDPK1_p-S6_0',
#  'PDPK1_p-S6_15',
#  'PDPK1_p-S6_30',
#  'PDPK1_p-S6_5',
#  'PDPK1_p-S6_60',
#  'PDPK1_p-SHP2_0',
#  'PDPK1_p-SHP2_15',
#  'PDPK1_p-SHP2_30',
#  'PDPK1_p-SHP2_5',
#  'PDPK1_p-SHP2_60',
#  'PDPK1_p-STAT5_0',
#  'PDPK1_p-STAT5_15',
#  'PDPK1_p-STAT5_30',
#  'PDPK1_p-STAT5_5',
#  'PDPK1_p-STAT5_60',
#  'PDPK1_p-p70S6K_0',
#  'PDPK1_p-p70S6K_15',
#  'PDPK1_p-p70S6K_30',
#  'PDPK1_p-p70S6K_5',
#  'PDPK1_p-p70S6K_60',
#  'PIK3CA_p-GSK3-Beta_30',
#  'PIK3CA_p-GSK3-Beta_60',
#  'PIK3CA_p-JNK_0',
#  'PIK3CA_p-JNK_15',
#  'PIK3CA_p-JNK_30',
#  'PIK3CA_p-JNK_5',
#  'PIK3CA_p-JNK_60',
#  'PIK3CA_p-MKK3-6_0',
#  'PIK3CA_p-MKK3-6_15',
#  'PIK3CA_p-MKK3-6_30',
#  'PIK3CA_p-MKK3-6_5',
#  'PIK3CA_p-MKK3-6_60',
#  'PIK3CA_p-SMAD1-5_0',
#  'PIK3CA_p-SMAD1-5_15',
#  'PIK3CA_p-SMAD1-5_30',
#  'PIK3CA_p-SMAD1-5_5',
#  'PIK3CA_p-SMAD1-5_60',
#  'PIK3CA_p-STAT1_0',
#  'PIK3CA_p-p38_0',
#  'PIK3CA_p-p38_15',
#  'PIK3CA_p-p38_30',
#  'PIK3CA_p-p38_5',
#  'PIK3CA_p-p38_60',
#  'PTPN11_p-JNK_0',
#  'PTPN11_p-JNK_15',
#  'PTPN11_p-JNK_30',
#  'PTPN11_p-JNK_60',
#  'PTPN11_p-MARCKS_15',
#  'PTPN11_p-MARCKS_5',
#  'PTPN11_p-MKK3-6_5',
#  'PTPN11_p-S6_0',
#  'PTPN11_p-S6_5',
#  'PTPN11_p-SMAD1-5_0',
#  'PTPN11_p-SMAD1-5_15',
#  'PTPN11_p-SMAD1-5_30',
#  'PTPN11_p-SMAD1-5_5',
#  'PTPN11_p-SMAD1-5_60',
#  'RPS6KA1_Beta-catenin_15',
#  'RPS6KA1_E-cadherin_15',
#  'RPS6KA1_p-BTK_0',
#  'RPS6KA1_p-BTK_15',
#  'RPS6KA1_p-BTK_30',
#  'RPS6KA1_p-BTK_5',
#  'RPS6KA1_p-BTK_60',
#  'RPS6KA1_p-ERK1-2_5',
#  'RPS6KA1_p-FAK_15',
#  'RPS6KA1_p-MEK1-2_15',
#  'RPS6KA1_p-MEK1-2_30',
#  'RPS6KA1_p-MKK3_15',
#  'RPS6KA1_p-PDPK1_0',
#  'RPS6KA1_p-PDPK1_15',
#  'RPS6KA1_p-PDPK1_30',
#  'RPS6KA1_p-PDPK1_5',
#  'RPS6KA1_p-PDPK1_60',
#  'RPS6KA1_p-PLCg2_15',
#  'RPS6KA1_p-SHP2_15',
#  'RPS6KA1_p-SHP2_30',
#  'RPS6KA1_p-SHP2_5',
#  'RPS6KA1_p-SHP2_60',
#  'RPS6KA1_p-SMAD2-3_15',
#  'RPS6KA1_p-SMAD2-3_30',
#  'RPS6KA1_p-SMAD2-3_5',
#  'RPS6KA1_p-SMAD2-3_60',
#  'RPS6KA1_p-STAT1_15',
#  'RPS6KA1_p-mTOR_15',
#  'RPS6KA1_p-p70S6K_0',
#  'RPS6KA1_p-p70S6K_15',
#  'RPS6KA1_p-p70S6K_30',
#  'RPS6KA1_p-p70S6K_5',
#  'RPS6KA1_p-p70S6K_60',
#  'RPS6KA1_p-p90RSK_0',
#  'RPS6KA1_p-p90RSK_15',
#  'RPS6KA1_p-p90RSK_30',
#  'RPS6KA1_p-p90RSK_5',
#  'RPS6KA1_p-p90RSK_60',
#  'RPS6KB1_p-ERK1-2_15',
#  'RPS6KB1_p-S6_0',
#  'RPS6KB1_p-S6_15',
#  'RPS6KB1_p-S6_30',
#  'RPS6KB1_p-S6_5',
#  'RPS6KB1_p-p70S6K_15',
#  'RPS6KB1_p-p70S6K_30',
#  'RPS6KB1_p-p70S6K_60',
#  'RPS6KB1_p-p90RSK_15',
#  'RPS6KB1_p-p90RSK_30',
#  'SRC_p-BTK_0',
#  'SRC_p-BTK_15',
#  'SRC_p-BTK_30',
#  'SRC_p-BTK_5',
#  'SRC_p-BTK_60',
#  'SRC_p-ERK1-2_0',
#  'SRC_p-ERK1-2_15',
#  'SRC_p-ERK1-2_30',
#  'SRC_p-ERK1-2_5',
#  'SRC_p-ERK1-2_60',
#  'SRC_p-FAK_0',
#  'SRC_p-FAK_15',
#  'SRC_p-FAK_30',
#  'SRC_p-FAK_5',
#  'SRC_p-FAK_60',
#  'SRC_p-JNK_0',
#  'SRC_p-PLCg2_0',
#  'SRC_p-PLCg2_15',
#  'SRC_p-PLCg2_30',
#  'SRC_p-PLCg2_5',
#  'SRC_p-PLCg2_60',
#  'SRC_p-SHP2_0',
#  'SRC_p-SHP2_15',
#  'SRC_p-SHP2_30',
#  'SRC_p-SHP2_5',
#  'SRC_p-SHP2_60',
#  'SRC_p-SMAD1-5_0',
#  'SRC_p-SMAD1-5_15',
#  'SRC_p-SMAD1-5_30',
#  'SRC_p-SMAD1-5_5',
#  'SRC_p-SMAD1-5_60',
#  'SRC_p-STAT3_0',
#  'SRC_p-STAT3_15',
#  'SRC_p-STAT3_30',
#  'SRC_p-STAT3_5',
#  'SRC_p-STAT3_60',
#  'SRC_p-STAT5_0',
#  'SRC_p-STAT5_15',
#  'SRC_p-STAT5_30',
#  'SRC_p-STAT5_5',
#  'SRC_p-STAT5_60',
#  'SRC_p-p38_0',
#  'SRC_p-p38_15',
#  'SRC_p-p38_30',
#  'SRC_p-p38_5',
#  'SRC_p-p38_60'}

# %%
hits_bp.difference(hits_dremi)
# Out:
# {'AKT1_Beta-catenin_0',
#  'AKT1_Beta-catenin_15',
#  'AKT1_Beta-catenin_60',
#  'AKT1_p-AKT_0',
#  'AKT1_p-BTK_0',
#  'AKT1_p-BTK_15',
#  'AKT1_p-BTK_30',
#  'AKT1_p-BTK_5',
#  'AKT1_p-BTK_60',
#  'AKT1_p-GSK3-Beta_0',
#  'AKT1_p-GSK3-Beta_15',
#  'AKT1_p-GSK3-Beta_30',
#  'AKT1_p-GSK3-Beta_5',
#  'AKT1_p-GSK3-Beta_60',
#  'AKT1_p-MKK3-6_0',
#  'AKT1_p-MKK3-6_15',
#  'AKT1_p-MKK3-6_30',
#  'AKT1_p-MKK3-6_5',
#  'AKT1_p-MKK3-6_60',
#  'AKT1_p-PDPK1_0',
#  'AKT1_p-PDPK1_30',
#  'AKT1_p-PDPK1_5',
#  'AKT1_p-PDPK1_60',
#  'AKT1_p-SMAD1-5_0',
#  'AKT1_p-SMAD1-5_30',
#  'AKT1_p-SMAD1-5_5',
#  'AKT1_p-SMAD2-3_0',
#  'AKT1_p-SMAD2-3_15',
#  'AKT1_p-SMAD2-3_30',
#  'AKT1_p-SMAD2-3_5',
#  'AKT1_p-SMAD2-3_60',
#  'AKT1_p-p70S6K_0',
#  'AKT1_p-p70S6K_15',
#  'AKT1_p-p70S6K_30',
#  'AKT1_p-p70S6K_5',
#  'AKT1_p-p70S6K_60',
#  'BRAF_p-MKK3-6_0',
#  'BRAF_p-MKK3-6_15',
#  'BRAF_p-MKK3-6_30',
#  'BRAF_p-MKK3-6_5',
#  'BRAF_p-MKK3-6_60',
#  'BRAF_p-S6_15',
#  'BRAF_p-SMAD1-5_15',
#  'BRAF_p-p38_15',
#  'CRAF_p-ERK1-2_5',
#  'CRAF_p-JNK_0',
#  'CRAF_p-JNK_5',
#  'CRAF_p-PLCg2_5',
#  'CRAF_p-S6_15',
#  'CRAF_p-S6_60',
#  'CRAF_p-SMAD1-5_30',
#  'CRAF_p-p90RSK_0',
#  'CRAF_p-p90RSK_5',
#  'GSK3B_Beta-catenin_0',
#  'GSK3B_Beta-catenin_30',
#  'GSK3B_Beta-catenin_5',
#  'GSK3B_Beta-catenin_60',
#  'GSK3B_E-cadherin_15',
#  'GSK3B_E-cadherin_5',
#  'GSK3B_p-BTK_15',
#  'GSK3B_p-BTK_30',
#  'GSK3B_p-BTK_5',
#  'GSK3B_p-BTK_60',
#  'GSK3B_p-FAK_0',
#  'GSK3B_p-FAK_15',
#  'GSK3B_p-FAK_5',
#  'GSK3B_p-FAK_60',
#  'GSK3B_p-MEK1-2_0',
#  'GSK3B_p-MEK1-2_30',
#  'GSK3B_p-MEK1-2_5',
#  'GSK3B_p-MEK1-2_60',
#  'GSK3B_p-PDPK1_0',
#  'GSK3B_p-PDPK1_15',
#  'GSK3B_p-PDPK1_30',
#  'GSK3B_p-PDPK1_5',
#  'GSK3B_p-PDPK1_60',
#  'GSK3B_p-S6_15',
#  'GSK3B_p-S6_5',
#  'GSK3B_p-SHP2_0',
#  'GSK3B_p-SHP2_15',
#  'GSK3B_p-SHP2_30',
#  'GSK3B_p-SHP2_60',
#  'GSK3B_p-STAT5_0',
#  'GSK3B_p-STAT5_30',
#  'GSK3B_p-STAT5_5',
#  'GSK3B_p-STAT5_60',
#  'GSK3B_p-p70S6K_0',
#  'GSK3B_p-p70S6K_15',
#  'GSK3B_p-p70S6K_30',
#  'GSK3B_p-p70S6K_5',
#  'GSK3B_p-p70S6K_60',
#  'GSK3B_p-p90RSK_5',
#  'HRAS_p-ERK1-2_60',
#  'HRAS_p-JNK_0',
#  'HRAS_p-JNK_15',
#  'HRAS_p-JNK_30',
#  'HRAS_p-JNK_5',
#  'HRAS_p-JNK_60',
#  'HRAS_p-SMAD1-5_0',
#  'HRAS_p-SMAD1-5_15',
#  'HRAS_p-SMAD1-5_30',
#  'HRAS_p-SMAD1-5_5',
#  'HRAS_p-SMAD1-5_60',
#  'HRAS_p-SMAD2-3_0',
#  'HRAS_p-SMAD2-3_15',
#  'HRAS_p-SMAD2-3_30',
#  'HRAS_p-SMAD2-3_5',
#  'HRAS_p-SMAD2-3_60',
#  'HRAS_p-p38_15',
#  'HRAS_p-p38_30',
#  'HRAS_p-p38_5',
#  'HRAS_p-p90RSK_60',
#  'KRAS_p-ERK1-2_15',
#  'KRAS_p-ERK1-2_30',
#  'KRAS_p-MKK3-6_15',
#  'KRAS_p-MKK3-6_30',
#  'KRAS_p-S6_60',
#  'KRAS_p-p90RSK_15',
#  'KRAS_p-p90RSK_30',
#  'KRAS_p-p90RSK_5',
#  'MAP2K1_Beta-catenin_60',
#  'MAP2K1_p-BTK_0',
#  'MAP2K1_p-BTK_30',
#  'MAP2K1_p-BTK_60',
#  'MAP2K1_p-GSK3-Beta_0',
#  'MAP2K1_p-GSK3-Beta_30',
#  'MAP2K1_p-GSK3-Beta_5',
#  'MAP2K1_p-GSK3-Beta_60',
#  'MAP2K1_p-MKK3-6_15',
#  'MAP2K1_p-MKK3-6_30',
#  'MAP2K1_p-MKK3-6_5',
#  'MAP2K1_p-MKK3_30',
#  'MAP2K1_p-MKK3_5',
#  'MAP2K1_p-MKK3_60',
#  'MAP2K1_p-SMAD1-5_30',
#  'MAP2K1_p-SMAD1-5_60',
#  'MAP2K1_p-SMAD2-3_5',
#  'MAP2K1_p-SMAD2-3_60',
#  'MAP2K1_p-p90RSK_5',
#  'MAP2K6_p-ERK1-2_15',
#  'MAP2K6_p-GSK3-Beta_0',
#  'MAP2K6_p-GSK3-Beta_15',
#  'MAP2K6_p-GSK3-Beta_30',
#  'MAP2K6_p-GSK3-Beta_5',
#  'MAP2K6_p-MKK3_30',
#  'MAP2K6_p-MKK3_5',
#  'MAP2K6_p-PDPK1_5',
#  'MAP2K6_p-SMAD1-5_15',
#  'MAP2K6_p-SMAD1-5_5',
#  'MAP2K6_p-STAT1_0',
#  'MAP2K6_p-STAT1_15',
#  'MAP2K6_p-STAT1_30',
#  'MAP2K6_p-STAT1_5',
#  'MAP2K6_p-STAT1_60',
#  'MAP2K6_p-STAT5_60',
#  'MAP2K7_p-ERK1-2_30',
#  'MAP2K7_p-JNK_60',
#  'MAP2K7_p-SMAD1-5_0',
#  'MAP2K7_p-SMAD1-5_15',
#  'MAP2K7_p-SMAD1-5_5',
#  'MAP2K7_p-SMAD1-5_60',
#  'MAP2K7_p-p90RSK_60',
#  'MAP3K5_Beta-catenin_30',
#  'MAP3K5_p-BTK_15',
#  'MAP3K5_p-BTK_30',
#  'MAP3K5_p-BTK_5',
#  'MAP3K5_p-BTK_60',
#  'MAP3K5_p-ERK1-2_60',
#  'MAP3K5_p-GSK3-Beta_0',
#  'MAP3K5_p-GSK3-Beta_30',
#  'MAP3K5_p-GSK3-Beta_60',
#  'MAP3K5_p-MAPKAPK2_15',
#  'MAP3K5_p-MKK3_0',
#  'MAP3K5_p-MKK3_30',
#  'MAP3K5_p-PDPK1_0',
#  'MAP3K5_p-PDPK1_15',
#  'MAP3K5_p-PDPK1_30',
#  'MAP3K5_p-PDPK1_5',
#  'MAP3K5_p-PDPK1_60',
#  'MAP3K5_p-SMAD1-5_15',
#  'MAP3K5_p-SMAD1-5_30',
#  'MAP3K5_p-SMAD1-5_5',
#  'MAP3K5_p-SMAD2-3_0',
#  'MAP3K5_p-SMAD2-3_15',
#  'MAP3K5_p-SMAD2-3_30',
#  'MAP3K5_p-SMAD2-3_5',
#  'MAP3K5_p-SMAD2-3_60',
#  'MAP3K5_p-STAT1_0',
#  'MAP3K5_p-STAT1_15',
#  'MAP3K5_p-STAT1_30',
#  'MAP3K5_p-STAT1_5',
#  'MAP3K5_p-STAT1_60',
#  'MAP3K5_p-p38_30',
#  'MAP3K5_p-p90RSK_5',
#  'MAP8_p-JNK_15',
#  'MAP8_p-MAPKAPK2_15',
#  'MAP8_p-PDPK1_0',
#  'MAP8_p-PDPK1_30',
#  'MAP8_p-PDPK1_60',
#  'MAP8_p-STAT1_15',
#  'MAP8_p-STAT3_15',
#  'MAP8_p-STAT5_30',
#  'MAP8_p-STAT5_5',
#  'MAP8_p-STAT5_60',
#  'MAP8_p-p38_30',
#  'MAP8_p-p38_5',
#  'MAP8_p-p70S6K_0',
#  'MAP8_p-p70S6K_60',
#  'MAPK14_p-ERK1-2_15',
#  'MAPK14_p-p90RSK_15',
#  'MAPK1_p-ERK1-2_0',
#  'MAPK1_p-JNK_30',
#  'MAPK1_p-JNK_60',
#  'MAPK1_p-MAPKAPK2_30',
#  'MAPK1_p-MAPKAPK2_60',
#  'MAPK1_p-SMAD2-3_5',
#  'MAPK1_p-STAT1_30',
#  'MAPK1_p-STAT1_60',
#  'MAPK1_p-p38_0',
#  'MAPK1_p-p38_15',
#  'MAPK1_p-p38_30',
#  'MAPK1_p-p38_60',
#  'MAPK1_p-p70S6K_15',
#  'MAPK1_p-p90RSK_15',
#  'MAPK1_p-p90RSK_5',
#  'PDPK1_p-BTK_0',
#  'PDPK1_p-BTK_15',
#  'PDPK1_p-BTK_30',
#  'PDPK1_p-BTK_5',
#  'PDPK1_p-BTK_60',
#  'PDPK1_p-FAK_30',
#  'PDPK1_p-MAPKAPK2_0',
#  'PDPK1_p-MAPKAPK2_15',
#  'PDPK1_p-MAPKAPK2_30',
#  'PDPK1_p-MAPKAPK2_5',
#  'PDPK1_p-S6_0',
#  'PDPK1_p-S6_15',
#  'PDPK1_p-S6_30',
#  'PDPK1_p-S6_5',
#  'PDPK1_p-S6_60',
#  'PDPK1_p-SHP2_15',
#  'PDPK1_p-SHP2_5',
#  'PIK3CA_p-GSK3-Beta_30',
#  'PIK3CA_p-GSK3-Beta_60',
#  'PIK3CA_p-JNK_0',
#  'PIK3CA_p-MKK3-6_0',
#  'PIK3CA_p-MKK3-6_15',
#  'PIK3CA_p-MKK3-6_30',
#  'PIK3CA_p-MKK3-6_5',
#  'PIK3CA_p-MKK3-6_60',
#  'PIK3CA_p-SMAD1-5_0',
#  'PIK3CA_p-SMAD1-5_15',
#  'PIK3CA_p-SMAD1-5_30',
#  'PIK3CA_p-SMAD1-5_5',
#  'PIK3CA_p-SMAD1-5_60',
#  'PIK3CA_p-STAT1_0',
#  'PIK3CA_p-p38_0',
#  'PIK3CA_p-p38_15',
#  'PIK3CA_p-p38_30',
#  'PIK3CA_p-p38_5',
#  'PTPN11_p-JNK_0',
#  'PTPN11_p-JNK_15',
#  'PTPN11_p-JNK_30',
#  'PTPN11_p-JNK_60',
#  'PTPN11_p-MARCKS_15',
#  'PTPN11_p-MKK3-6_5',
#  'RPS6KA1_p-ERK1-2_5',
#  'RPS6KA1_p-FAK_15',
#  'RPS6KA1_p-MEK1-2_15',
#  'RPS6KA1_p-MEK1-2_30',
#  'RPS6KA1_p-MKK3_15',
#  'RPS6KA1_p-PDPK1_0',
#  'RPS6KA1_p-PDPK1_5',
#  'RPS6KA1_p-PDPK1_60',
#  'RPS6KA1_p-PLCg2_15',
#  'RPS6KA1_p-SHP2_30',
#  'RPS6KA1_p-SHP2_5',
#  'RPS6KA1_p-SHP2_60',
#  'RPS6KA1_p-SMAD2-3_30',
#  'RPS6KA1_p-SMAD2-3_5',
#  'RPS6KA1_p-SMAD2-3_60',
#  'RPS6KA1_p-STAT1_15',
#  'RPS6KA1_p-mTOR_15',
#  'RPS6KB1_p-ERK1-2_15',
#  'RPS6KB1_p-S6_5',
#  'RPS6KB1_p-p70S6K_15',
#  'RPS6KB1_p-p70S6K_30',
#  'RPS6KB1_p-p70S6K_60',
#  'RPS6KB1_p-p90RSK_15',
#  'RPS6KB1_p-p90RSK_30',
#  'SRC_p-JNK_0',
#  'SRC_p-SMAD1-5_0',
#  'SRC_p-SMAD1-5_15',
#  'SRC_p-SMAD1-5_30',
#  'SRC_p-SMAD1-5_5',
#  'SRC_p-SMAD1-5_60'}

# %%
hits_bp.difference(hits_dremi.union(hits_sp))
# Out:
# {'AKT1_Beta-catenin_0',
#  'AKT1_Beta-catenin_15',
#  'AKT1_Beta-catenin_60',
#  'AKT1_p-BTK_0',
#  'AKT1_p-BTK_15',
#  'AKT1_p-BTK_30',
#  'AKT1_p-BTK_5',
#  'AKT1_p-BTK_60',
#  'AKT1_p-GSK3-Beta_0',
#  'AKT1_p-GSK3-Beta_15',
#  'AKT1_p-GSK3-Beta_30',
#  'AKT1_p-GSK3-Beta_5',
#  'AKT1_p-GSK3-Beta_60',
#  'AKT1_p-SMAD2-3_0',
#  'AKT1_p-SMAD2-3_15',
#  'AKT1_p-SMAD2-3_30',
#  'AKT1_p-SMAD2-3_5',
#  'AKT1_p-SMAD2-3_60',
#  'BRAF_p-S6_15',
#  'CRAF_p-JNK_0',
#  'CRAF_p-PLCg2_5',
#  'CRAF_p-SMAD1-5_30',
#  'GSK3B_E-cadherin_5',
#  'GSK3B_p-BTK_30',
#  'GSK3B_p-FAK_0',
#  'GSK3B_p-FAK_15',
#  'GSK3B_p-FAK_5',
#  'GSK3B_p-MEK1-2_5',
#  'GSK3B_p-S6_5',
#  'GSK3B_p-p90RSK_5',
#  'KRAS_p-ERK1-2_30',
#  'KRAS_p-S6_60',
#  'KRAS_p-p90RSK_30',
#  'MAP2K1_Beta-catenin_60',
#  'MAP2K1_p-BTK_0',
#  'MAP2K1_p-BTK_30',
#  'MAP2K1_p-BTK_60',
#  'MAP2K1_p-GSK3-Beta_0',
#  'MAP2K1_p-GSK3-Beta_30',
#  'MAP2K1_p-GSK3-Beta_5',
#  'MAP2K1_p-GSK3-Beta_60',
#  'MAP2K1_p-MKK3-6_30',
#  'MAP2K1_p-MKK3_30',
#  'MAP2K1_p-MKK3_5',
#  'MAP2K1_p-MKK3_60',
#  'MAP2K1_p-SMAD1-5_30',
#  'MAP2K1_p-SMAD1-5_60',
#  'MAP2K1_p-SMAD2-3_5',
#  'MAP2K1_p-SMAD2-3_60',
#  'MAP2K6_p-GSK3-Beta_0',
#  'MAP2K6_p-GSK3-Beta_15',
#  'MAP2K6_p-GSK3-Beta_30',
#  'MAP2K6_p-MKK3_30',
#  'MAP2K6_p-PDPK1_5',
#  'MAP2K6_p-SMAD1-5_5',
#  'MAP2K7_p-ERK1-2_30',
#  'MAP2K7_p-SMAD1-5_15',
#  'MAP2K7_p-SMAD1-5_5',
#  'MAP3K5_Beta-catenin_30',
#  'MAP3K5_p-BTK_15',
#  'MAP3K5_p-BTK_30',
#  'MAP3K5_p-BTK_5',
#  'MAP3K5_p-BTK_60',
#  'MAP3K5_p-GSK3-Beta_30',
#  'MAP3K5_p-p90RSK_5',
#  'MAP8_p-MAPKAPK2_15',
#  'MAP8_p-STAT1_15',
#  'MAP8_p-STAT3_15',
#  'MAPK1_p-SMAD2-3_5',
#  'MAPK1_p-p70S6K_15',
#  'MAPK1_p-p90RSK_15',
#  'PDPK1_p-MAPKAPK2_5',
#  'PDPK1_p-S6_5',
#  'PIK3CA_p-GSK3-Beta_60',
#  'PIK3CA_p-SMAD1-5_5',
#  'PIK3CA_p-STAT1_0',
#  'PIK3CA_p-p38_5',
#  'PTPN11_p-JNK_0',
#  'RPS6KA1_p-STAT1_15',
#  'RPS6KB1_p-S6_5'}

# %%
hits_bp.difference(hits_sp)
# Out:
# {'AKT1_Beta-catenin_0',
#  'AKT1_Beta-catenin_15',
#  'AKT1_Beta-catenin_30',
#  'AKT1_Beta-catenin_5',
#  'AKT1_Beta-catenin_60',
#  'AKT1_p-BTK_0',
#  'AKT1_p-BTK_15',
#  'AKT1_p-BTK_30',
#  'AKT1_p-BTK_5',
#  'AKT1_p-BTK_60',
#  'AKT1_p-GSK3-Beta_0',
#  'AKT1_p-GSK3-Beta_15',
#  'AKT1_p-GSK3-Beta_30',
#  'AKT1_p-GSK3-Beta_5',
#  'AKT1_p-GSK3-Beta_60',
#  'AKT1_p-SMAD2-3_0',
#  'AKT1_p-SMAD2-3_15',
#  'AKT1_p-SMAD2-3_30',
#  'AKT1_p-SMAD2-3_5',
#  'AKT1_p-SMAD2-3_60',
#  'BRAF_p-S6_0',
#  'BRAF_p-S6_15',
#  'CRAF_p-JNK_0',
#  'CRAF_p-PLCg2_5',
#  'CRAF_p-SMAD1-5_30',
#  'GSK3B_E-cadherin_5',
#  'GSK3B_p-BTK_30',
#  'GSK3B_p-FAK_0',
#  'GSK3B_p-FAK_15',
#  'GSK3B_p-FAK_5',
#  'GSK3B_p-MEK1-2_5',
#  'GSK3B_p-S6_5',
#  'GSK3B_p-p90RSK_5',
#  'KRAS_p-ERK1-2_30',
#  'KRAS_p-S6_15',
#  'KRAS_p-S6_60',
#  'KRAS_p-p90RSK_30',
#  'MAP2K1_Beta-catenin_0',
#  'MAP2K1_Beta-catenin_5',
#  'MAP2K1_Beta-catenin_60',
#  'MAP2K1_p-BTK_0',
#  'MAP2K1_p-BTK_30',
#  'MAP2K1_p-BTK_60',
#  'MAP2K1_p-GSK3-Beta_0',
#  'MAP2K1_p-GSK3-Beta_30',
#  'MAP2K1_p-GSK3-Beta_5',
#  'MAP2K1_p-GSK3-Beta_60',
#  'MAP2K1_p-MARCKS_5',
#  'MAP2K1_p-MKK3-6_0',
#  'MAP2K1_p-MKK3-6_30',
#  'MAP2K1_p-MKK3-6_60',
#  'MAP2K1_p-MKK3_30',
#  'MAP2K1_p-MKK3_5',
#  'MAP2K1_p-MKK3_60',
#  'MAP2K1_p-SMAD1-5_30',
#  'MAP2K1_p-SMAD1-5_60',
#  'MAP2K1_p-SMAD2-3_5',
#  'MAP2K1_p-SMAD2-3_60',
#  'MAP2K1_p-p90RSK_15',
#  'MAP2K6_p-GSK3-Beta_0',
#  'MAP2K6_p-GSK3-Beta_15',
#  'MAP2K6_p-GSK3-Beta_30',
#  'MAP2K6_p-MKK3_30',
#  'MAP2K6_p-PDPK1_5',
#  'MAP2K6_p-SMAD1-5_5',
#  'MAP2K7_p-ERK1-2_30',
#  'MAP2K7_p-SMAD1-5_15',
#  'MAP2K7_p-SMAD1-5_5',
#  'MAP3K5_Beta-catenin_30',
#  'MAP3K5_p-BTK_15',
#  'MAP3K5_p-BTK_30',
#  'MAP3K5_p-BTK_5',
#  'MAP3K5_p-BTK_60',
#  'MAP3K5_p-GSK3-Beta_30',
#  'MAP3K5_p-p90RSK_5',
#  'MAP8_p-MAPKAPK2_15',
#  'MAP8_p-STAT1_15',
#  'MAP8_p-STAT3_15',
#  'MAPK1_p-SMAD2-3_5',
#  'MAPK1_p-p70S6K_15',
#  'MAPK1_p-p90RSK_15',
#  'PDPK1_p-MAPKAPK2_5',
#  'PDPK1_p-S6_5',
#  'PIK3CA_p-GSK3-Beta_60',
#  'PIK3CA_p-SMAD1-5_5',
#  'PIK3CA_p-STAT1_0',
#  'PIK3CA_p-p38_5',
#  'PTPN11_p-JNK_0',
#  'RPS6KA1_p-STAT1_15',
#  'RPS6KB1_p-S6_30',
#  'RPS6KB1_p-S6_5'}

# %%
hits_dremi.difference(hits_bp)
# Out:
# {'AKT1_p-S6_0',
#  'AKT1_p-S6_5',
#  'BRAF_p-SMAD1-5_60',
#  'CRAF_p-AKT_15',
#  'CRAF_p-AKT_5',
#  'CRAF_p-AKT_60',
#  'GSK3B_p-SMAD1-5_30',
#  'HRAS_p-S6_15',
#  'KRAS_p-PLCg2_5',
#  'KRAS_p-S6_5',
#  'MAP2K1_p-S6_0',
#  'MAP2K1_p-S6_15',
#  'MAP2K1_p-S6_30',
#  'MAP2K6_Beta-catenin_0',
#  'MAP2K6_Beta-catenin_15',
#  'MAP2K6_Beta-catenin_30',
#  'MAP2K6_Beta-catenin_5',
#  'MAP2K6_Beta-catenin_60',
#  'MAP2K6_E-cadherin_5',
#  'MAP2K6_p-CREB_15',
#  'MAP2K6_p-CREB_30',
#  'MAP2K6_p-CREB_5',
#  'MAP2K6_p-MARCKS_15',
#  'MAP2K6_p-MARCKS_60',
#  'MAP3K5_Beta-catenin_0',
#  'MAP3K5_Beta-catenin_5',
#  'MAP3K5_Beta-catenin_60',
#  'MAP8_p-NfkB_5',
#  'MAP8_p-PLCg2_0',
#  'MAP8_p-PLCg2_30',
#  'MAP8_p-PLCg2_5',
#  'MAP8_p-PLCg2_60',
#  'MAP8_p-S6_5',
#  'MAP8_p-S6_60',
#  'MAP8_p-STAT3_0',
#  'MAP8_p-STAT3_60',
#  'MAPK14_p-S6_15',
#  'MAPK14_p-S6_30',
#  'MAPK1_p-SMAD1-5_15',
#  'PDPK1_E-cadherin_30',
#  'PDPK1_E-cadherin_60',
#  'PDPK1_p-AKT_0',
#  'PTPN11_p-MARCKS_0',
#  'PTPN11_p-S6_15',
#  'RPS6KB1_p-S6_60',
#  'SRC_Beta-catenin_0',
#  'SRC_Beta-catenin_30',
#  'SRC_E-cadherin_30',
#  'SRC_E-cadherin_60',
#  'SRC_p-CREB_15'}

# %%
hits_dremi.difference(hits_bp.union(hits_sp))
# Out:
# {'AKT1_p-S6_0',
#  'AKT1_p-S6_5',
#  'CRAF_p-AKT_15',
#  'CRAF_p-AKT_5',
#  'CRAF_p-AKT_60',
#  'GSK3B_p-SMAD1-5_30',
#  'HRAS_p-S6_15',
#  'KRAS_p-PLCg2_5',
#  'KRAS_p-S6_5',
#  'MAP2K1_p-S6_0',
#  'MAP2K1_p-S6_15',
#  'MAP2K1_p-S6_30',
#  'MAP2K6_Beta-catenin_0',
#  'MAP2K6_Beta-catenin_15',
#  'MAP2K6_Beta-catenin_30',
#  'MAP2K6_Beta-catenin_5',
#  'MAP2K6_Beta-catenin_60',
#  'MAP2K6_E-cadherin_5',
#  'MAP2K6_p-CREB_15',
#  'MAP2K6_p-CREB_30',
#  'MAP2K6_p-CREB_5',
#  'MAP2K6_p-MARCKS_15',
#  'MAP2K6_p-MARCKS_60',
#  'MAP3K5_Beta-catenin_0',
#  'MAP3K5_Beta-catenin_5',
#  'MAP3K5_Beta-catenin_60',
#  'MAP8_p-NfkB_5',
#  'MAP8_p-S6_5',
#  'MAP8_p-S6_60',
#  'MAPK14_p-S6_15',
#  'MAPK14_p-S6_30',
#  'MAPK1_p-SMAD1-5_15',
#  'PDPK1_E-cadherin_30',
#  'PDPK1_E-cadherin_60',
#  'PDPK1_p-AKT_0',
#  'RPS6KB1_p-S6_60',
#  'SRC_Beta-catenin_0',
#  'SRC_Beta-catenin_30',
#  'SRC_E-cadherin_30',
#  'SRC_E-cadherin_60',
#  'SRC_p-CREB_15'}

# %%
hits_dremi.difference(hits_sp)
# Out:
# {'AKT1_Beta-catenin_30',
#  'AKT1_Beta-catenin_5',
#  'AKT1_p-S6_0',
#  'AKT1_p-S6_5',
#  'BRAF_p-S6_0',
#  'CRAF_p-AKT_15',
#  'CRAF_p-AKT_5',
#  'CRAF_p-AKT_60',
#  'GSK3B_p-SMAD1-5_30',
#  'HRAS_p-S6_15',
#  'KRAS_p-PLCg2_5',
#  'KRAS_p-S6_15',
#  'KRAS_p-S6_5',
#  'MAP2K1_Beta-catenin_0',
#  'MAP2K1_Beta-catenin_5',
#  'MAP2K1_p-MARCKS_5',
#  'MAP2K1_p-MKK3-6_0',
#  'MAP2K1_p-MKK3-6_60',
#  'MAP2K1_p-S6_0',
#  'MAP2K1_p-S6_15',
#  'MAP2K1_p-S6_30',
#  'MAP2K1_p-p90RSK_15',
#  'MAP2K6_Beta-catenin_0',
#  'MAP2K6_Beta-catenin_15',
#  'MAP2K6_Beta-catenin_30',
#  'MAP2K6_Beta-catenin_5',
#  'MAP2K6_Beta-catenin_60',
#  'MAP2K6_E-cadherin_5',
#  'MAP2K6_p-CREB_15',
#  'MAP2K6_p-CREB_30',
#  'MAP2K6_p-CREB_5',
#  'MAP2K6_p-MARCKS_15',
#  'MAP2K6_p-MARCKS_60',
#  'MAP3K5_Beta-catenin_0',
#  'MAP3K5_Beta-catenin_5',
#  'MAP3K5_Beta-catenin_60',
#  'MAP8_p-NfkB_5',
#  'MAP8_p-S6_5',
#  'MAP8_p-S6_60',
#  'MAPK14_p-S6_15',
#  'MAPK14_p-S6_30',
#  'MAPK1_p-SMAD1-5_15',
#  'PDPK1_E-cadherin_30',
#  'PDPK1_E-cadherin_60',
#  'PDPK1_p-AKT_0',
#  'RPS6KB1_p-S6_30',
#  'RPS6KB1_p-S6_60',
#  'SRC_Beta-catenin_0',
#  'SRC_Beta-catenin_30',
#  'SRC_E-cadherin_30',
#  'SRC_E-cadherin_60',
#  'SRC_p-CREB_15'}

# %%
hits_sp.difference(hits_bp)
# Out:
# {'AKT1_p-PDPK1_15',
#  'AKT1_p-SMAD1-5_15',
#  'AKT1_p-STAT5_0',
#  'AKT1_p-STAT5_30',
#  'AKT1_p-STAT5_5',
#  'AKT1_p-p38_5',
#  'BRAF_p-JNK_0',
#  'BRAF_p-JNK_5',
#  'BRAF_p-SMAD1-5_60',
#  'BRAF_p-p38_5',
#  'BRAF_p-p90RSK_60',
#  'CRAF_p-ERK1-2_0',
#  'CRAF_p-JNK_15',
#  'CRAF_p-PLCg2_15',
#  'GSK3B_E-cadherin_60',
#  'HRAS_p-MAPKAPK2_15',
#  'HRAS_p-MAPKAPK2_30',
#  'HRAS_p-MAPKAPK2_60',
#  'HRAS_p-p38_0',
#  'HRAS_p-p38_60',
#  'KRAS_Beta-catenin_5',
#  'KRAS_p-MKK3-6_5',
#  'KRAS_p-SMAD1-5_15',
#  'KRAS_p-SMAD1-5_30',
#  'KRAS_p-SMAD1-5_5',
#  'KRAS_p-SMAD1-5_60',
#  'MAP2K6_p-MKK3_15',
#  'MAP2K6_p-SMAD1-5_0',
#  'MAP2K7_p-ERK1-2_60',
#  'MAP2K7_p-STAT5_0',
#  'MAP2K7_p-p38_60',
#  'MAP3K5_p-MKK3_60',
#  'MAP3K5_p-p70S6K_0',
#  'MAP3K5_p-p70S6K_30',
#  'MAP3K5_p-p70S6K_60',
#  'MAP3K5_p-p90RSK_60',
#  'MAP8_p-PDPK1_5',
#  'MAP8_p-PLCg2_0',
#  'MAP8_p-PLCg2_30',
#  'MAP8_p-PLCg2_5',
#  'MAP8_p-PLCg2_60',
#  'MAP8_p-SMAD2-3_0',
#  'MAP8_p-SMAD2-3_15',
#  'MAP8_p-SMAD2-3_30',
#  'MAP8_p-STAT3_0',
#  'MAP8_p-STAT3_5',
#  'MAP8_p-STAT3_60',
#  'MAP8_p-STAT5_0',
#  'MAP8_p-p70S6K_30',
#  'MAPK14_p-ERK1-2_5',
#  'MAPK14_p-ERK1-2_60',
#  'MAPK14_p-STAT5_5',
#  'MAPK14_p-p90RSK_5',
#  'MAPK14_p-p90RSK_60',
#  'MAPK1_p-AMPKalpha_15',
#  'MAPK1_p-JNK_0',
#  'MAPK1_p-MAPKAPK2_5',
#  'MAPK1_p-MKK3-6_60',
#  'MAPK1_p-STAT1_15',
#  'MAPK1_p-STAT5_5',
#  'MAPK1_p-p38_5',
#  'PIK3CA_p-GSK3-Beta_0',
#  'PIK3CA_p-SMAD2-3_0',
#  'PIK3CA_p-p90RSK_60',
#  'PTPN11_p-JNK_5',
#  'PTPN11_p-MARCKS_0',
#  'PTPN11_p-MARCKS_60',
#  'PTPN11_p-S6_15',
#  'PTPN11_p-p90RSK_15',
#  'PTPN11_p-p90RSK_60',
#  'RPS6KA1_E-cadherin_30',
#  'RPS6KA1_E-cadherin_5',
#  'RPS6KA1_p-MEK1-2_5',
#  'RPS6KA1_p-SHP2_0',
#  'RPS6KA1_p-STAT5_0',
#  'RPS6KA1_p-STAT5_15',
#  'RPS6KA1_p-STAT5_30',
#  'RPS6KA1_p-STAT5_5',
#  'RPS6KA1_p-STAT5_60',
#  'RPS6KB1_p-STAT5_60',
#  'RPS6KB1_p-p90RSK_60',
#  'SRC_p-JNK_15',
#  'SRC_p-JNK_30',
#  'SRC_p-JNK_5'}

# %%
hits_sp.difference(hits_bp.union(hits_dremi))
# Out:
# {'AKT1_p-PDPK1_15',
#  'AKT1_p-SMAD1-5_15',
#  'AKT1_p-STAT5_0',
#  'AKT1_p-STAT5_30',
#  'AKT1_p-STAT5_5',
#  'AKT1_p-p38_5',
#  'BRAF_p-JNK_0',
#  'BRAF_p-JNK_5',
#  'BRAF_p-p38_5',
#  'BRAF_p-p90RSK_60',
#  'CRAF_p-ERK1-2_0',
#  'CRAF_p-JNK_15',
#  'CRAF_p-PLCg2_15',
#  'GSK3B_E-cadherin_60',
#  'HRAS_p-MAPKAPK2_15',
#  'HRAS_p-MAPKAPK2_30',
#  'HRAS_p-MAPKAPK2_60',
#  'HRAS_p-p38_0',
#  'HRAS_p-p38_60',
#  'KRAS_Beta-catenin_5',
#  'KRAS_p-MKK3-6_5',
#  'KRAS_p-SMAD1-5_15',
#  'KRAS_p-SMAD1-5_30',
#  'KRAS_p-SMAD1-5_5',
#  'KRAS_p-SMAD1-5_60',
#  'MAP2K6_p-MKK3_15',
#  'MAP2K6_p-SMAD1-5_0',
#  'MAP2K7_p-ERK1-2_60',
#  'MAP2K7_p-STAT5_0',
#  'MAP2K7_p-p38_60',
#  'MAP3K5_p-MKK3_60',
#  'MAP3K5_p-p70S6K_0',
#  'MAP3K5_p-p70S6K_30',
#  'MAP3K5_p-p70S6K_60',
#  'MAP3K5_p-p90RSK_60',
#  'MAP8_p-PDPK1_5',
#  'MAP8_p-SMAD2-3_0',
#  'MAP8_p-SMAD2-3_15',
#  'MAP8_p-SMAD2-3_30',
#  'MAP8_p-STAT3_5',
#  'MAP8_p-STAT5_0',
#  'MAP8_p-p70S6K_30',
#  'MAPK14_p-ERK1-2_5',
#  'MAPK14_p-ERK1-2_60',
#  'MAPK14_p-STAT5_5',
#  'MAPK14_p-p90RSK_5',
#  'MAPK14_p-p90RSK_60',
#  'MAPK1_p-AMPKalpha_15',
#  'MAPK1_p-JNK_0',
#  'MAPK1_p-MAPKAPK2_5',
#  'MAPK1_p-MKK3-6_60',
#  'MAPK1_p-STAT1_15',
#  'MAPK1_p-STAT5_5',
#  'MAPK1_p-p38_5',
#  'PIK3CA_p-GSK3-Beta_0',
#  'PIK3CA_p-SMAD2-3_0',
#  'PIK3CA_p-p90RSK_60',
#  'PTPN11_p-JNK_5',
#  'PTPN11_p-MARCKS_60',
#  'PTPN11_p-p90RSK_15',
#  'PTPN11_p-p90RSK_60',
#  'RPS6KA1_E-cadherin_30',
#  'RPS6KA1_E-cadherin_5',
#  'RPS6KA1_p-MEK1-2_5',
#  'RPS6KA1_p-SHP2_0',
#  'RPS6KA1_p-STAT5_0',
#  'RPS6KA1_p-STAT5_15',
#  'RPS6KA1_p-STAT5_30',
#  'RPS6KA1_p-STAT5_5',
#  'RPS6KA1_p-STAT5_60',
#  'RPS6KB1_p-STAT5_60',
#  'RPS6KB1_p-p90RSK_60',
#  'SRC_p-JNK_15',
#  'SRC_p-JNK_30',
#  'SRC_p-JNK_5'}

# %%
hits_bp.union(hits_sp).difference(hits_dremi)
# Out:
# {'AKT1_Beta-catenin_0',
#  'AKT1_Beta-catenin_15',
#  'AKT1_Beta-catenin_60',
#  'AKT1_p-AKT_0',
#  'AKT1_p-BTK_0',
#  'AKT1_p-BTK_15',
#  'AKT1_p-BTK_30',
#  'AKT1_p-BTK_5',
#  'AKT1_p-BTK_60',
#  'AKT1_p-GSK3-Beta_0',
#  'AKT1_p-GSK3-Beta_15',
#  'AKT1_p-GSK3-Beta_30',
#  'AKT1_p-GSK3-Beta_5',
#  'AKT1_p-GSK3-Beta_60',
#  'AKT1_p-MKK3-6_0',
#  'AKT1_p-MKK3-6_15',
#  'AKT1_p-MKK3-6_30',
#  'AKT1_p-MKK3-6_5',
#  'AKT1_p-MKK3-6_60',
#  'AKT1_p-PDPK1_0',
#  'AKT1_p-PDPK1_15',
#  'AKT1_p-PDPK1_30',
#  'AKT1_p-PDPK1_5',
#  'AKT1_p-PDPK1_60',
#  'AKT1_p-SMAD1-5_0',
#  'AKT1_p-SMAD1-5_15',
#  'AKT1_p-SMAD1-5_30',
#  'AKT1_p-SMAD1-5_5',
#  'AKT1_p-SMAD2-3_0',
#  'AKT1_p-SMAD2-3_15',
#  'AKT1_p-SMAD2-3_30',
#  'AKT1_p-SMAD2-3_5',
#  'AKT1_p-SMAD2-3_60',
#  'AKT1_p-STAT5_0',
#  'AKT1_p-STAT5_30',
#  'AKT1_p-STAT5_5',
#  'AKT1_p-p38_5',
#  'AKT1_p-p70S6K_0',
#  'AKT1_p-p70S6K_15',
#  'AKT1_p-p70S6K_30',
#  'AKT1_p-p70S6K_5',
#  'AKT1_p-p70S6K_60',
#  'BRAF_p-JNK_0',
#  'BRAF_p-JNK_5',
#  'BRAF_p-MKK3-6_0',
#  'BRAF_p-MKK3-6_15',
#  'BRAF_p-MKK3-6_30',
#  'BRAF_p-MKK3-6_5',
#  'BRAF_p-MKK3-6_60',
#  'BRAF_p-S6_15',
#  'BRAF_p-SMAD1-5_15',
#  'BRAF_p-p38_15',
#  'BRAF_p-p38_5',
#  'BRAF_p-p90RSK_60',
#  'CRAF_p-ERK1-2_0',
#  'CRAF_p-ERK1-2_5',
#  'CRAF_p-JNK_0',
#  'CRAF_p-JNK_15',
#  'CRAF_p-JNK_5',
#  'CRAF_p-PLCg2_15',
#  'CRAF_p-PLCg2_5',
#  'CRAF_p-S6_15',
#  'CRAF_p-S6_60',
#  'CRAF_p-SMAD1-5_30',
#  'CRAF_p-p90RSK_0',
#  'CRAF_p-p90RSK_5',
#  'GSK3B_Beta-catenin_0',
#  'GSK3B_Beta-catenin_30',
#  'GSK3B_Beta-catenin_5',
#  'GSK3B_Beta-catenin_60',
#  'GSK3B_E-cadherin_15',
#  'GSK3B_E-cadherin_5',
#  'GSK3B_E-cadherin_60',
#  'GSK3B_p-BTK_15',
#  'GSK3B_p-BTK_30',
#  'GSK3B_p-BTK_5',
#  'GSK3B_p-BTK_60',
#  'GSK3B_p-FAK_0',
#  'GSK3B_p-FAK_15',
#  'GSK3B_p-FAK_5',
#  'GSK3B_p-FAK_60',
#  'GSK3B_p-MEK1-2_0',
#  'GSK3B_p-MEK1-2_30',
#  'GSK3B_p-MEK1-2_5',
#  'GSK3B_p-MEK1-2_60',
#  'GSK3B_p-PDPK1_0',
#  'GSK3B_p-PDPK1_15',
#  'GSK3B_p-PDPK1_30',
#  'GSK3B_p-PDPK1_5',
#  'GSK3B_p-PDPK1_60',
#  'GSK3B_p-S6_15',
#  'GSK3B_p-S6_5',
#  'GSK3B_p-SHP2_0',
#  'GSK3B_p-SHP2_15',
#  'GSK3B_p-SHP2_30',
#  'GSK3B_p-SHP2_60',
#  'GSK3B_p-STAT5_0',
#  'GSK3B_p-STAT5_30',
#  'GSK3B_p-STAT5_5',
#  'GSK3B_p-STAT5_60',
#  'GSK3B_p-p70S6K_0',
#  'GSK3B_p-p70S6K_15',
#  'GSK3B_p-p70S6K_30',
#  'GSK3B_p-p70S6K_5',
#  'GSK3B_p-p70S6K_60',
#  'GSK3B_p-p90RSK_5',
#  'HRAS_p-ERK1-2_60',
#  'HRAS_p-JNK_0',
#  'HRAS_p-JNK_15',
#  'HRAS_p-JNK_30',
#  'HRAS_p-JNK_5',
#  'HRAS_p-JNK_60',
#  'HRAS_p-MAPKAPK2_15',
#  'HRAS_p-MAPKAPK2_30',
#  'HRAS_p-MAPKAPK2_60',
#  'HRAS_p-SMAD1-5_0',
#  'HRAS_p-SMAD1-5_15',
#  'HRAS_p-SMAD1-5_30',
#  'HRAS_p-SMAD1-5_5',
#  'HRAS_p-SMAD1-5_60',
#  'HRAS_p-SMAD2-3_0',
#  'HRAS_p-SMAD2-3_15',
#  'HRAS_p-SMAD2-3_30',
#  'HRAS_p-SMAD2-3_5',
#  'HRAS_p-SMAD2-3_60',
#  'HRAS_p-p38_0',
#  'HRAS_p-p38_15',
#  'HRAS_p-p38_30',
#  'HRAS_p-p38_5',
#  'HRAS_p-p38_60',
#  'HRAS_p-p90RSK_60',
#  'KRAS_Beta-catenin_5',
#  'KRAS_p-ERK1-2_15',
#  'KRAS_p-ERK1-2_30',
#  'KRAS_p-MKK3-6_15',
#  'KRAS_p-MKK3-6_30',
#  'KRAS_p-MKK3-6_5',
#  'KRAS_p-S6_60',
#  'KRAS_p-SMAD1-5_15',
#  'KRAS_p-SMAD1-5_30',
#  'KRAS_p-SMAD1-5_5',
#  'KRAS_p-SMAD1-5_60',
#  'KRAS_p-p90RSK_15',
#  'KRAS_p-p90RSK_30',
#  'KRAS_p-p90RSK_5',
#  'MAP2K1_Beta-catenin_60',
#  'MAP2K1_p-BTK_0',
#  'MAP2K1_p-BTK_30',
#  'MAP2K1_p-BTK_60',
#  'MAP2K1_p-GSK3-Beta_0',
#  'MAP2K1_p-GSK3-Beta_30',
#  'MAP2K1_p-GSK3-Beta_5',
#  'MAP2K1_p-GSK3-Beta_60',
#  'MAP2K1_p-MKK3-6_15',
#  'MAP2K1_p-MKK3-6_30',
#  'MAP2K1_p-MKK3-6_5',
#  'MAP2K1_p-MKK3_30',
#  'MAP2K1_p-MKK3_5',
#  'MAP2K1_p-MKK3_60',
#  'MAP2K1_p-SMAD1-5_30',
#  'MAP2K1_p-SMAD1-5_60',
#  'MAP2K1_p-SMAD2-3_5',
#  'MAP2K1_p-SMAD2-3_60',
#  'MAP2K1_p-p90RSK_5',
#  'MAP2K6_p-ERK1-2_15',
#  'MAP2K6_p-GSK3-Beta_0',
#  'MAP2K6_p-GSK3-Beta_15',
#  'MAP2K6_p-GSK3-Beta_30',
#  'MAP2K6_p-GSK3-Beta_5',
#  'MAP2K6_p-MKK3_15',
#  'MAP2K6_p-MKK3_30',
#  'MAP2K6_p-MKK3_5',
#  'MAP2K6_p-PDPK1_5',
#  'MAP2K6_p-SMAD1-5_0',
#  'MAP2K6_p-SMAD1-5_15',
#  'MAP2K6_p-SMAD1-5_5',
#  'MAP2K6_p-STAT1_0',
#  'MAP2K6_p-STAT1_15',
#  'MAP2K6_p-STAT1_30',
#  'MAP2K6_p-STAT1_5',
#  'MAP2K6_p-STAT1_60',
#  'MAP2K6_p-STAT5_60',
#  'MAP2K7_p-ERK1-2_30',
#  'MAP2K7_p-ERK1-2_60',
#  'MAP2K7_p-JNK_60',
#  'MAP2K7_p-SMAD1-5_0',
#  'MAP2K7_p-SMAD1-5_15',
#  'MAP2K7_p-SMAD1-5_5',
#  'MAP2K7_p-SMAD1-5_60',
#  'MAP2K7_p-STAT5_0',
#  'MAP2K7_p-p38_60',
#  'MAP2K7_p-p90RSK_60',
#  'MAP3K5_Beta-catenin_30',
#  'MAP3K5_p-BTK_15',
#  'MAP3K5_p-BTK_30',
#  'MAP3K5_p-BTK_5',
#  'MAP3K5_p-BTK_60',
#  'MAP3K5_p-ERK1-2_60',
#  'MAP3K5_p-GSK3-Beta_0',
#  'MAP3K5_p-GSK3-Beta_30',
#  'MAP3K5_p-GSK3-Beta_60',
#  'MAP3K5_p-MAPKAPK2_15',
#  'MAP3K5_p-MKK3_0',
#  'MAP3K5_p-MKK3_30',
#  'MAP3K5_p-MKK3_60',
#  'MAP3K5_p-PDPK1_0',
#  'MAP3K5_p-PDPK1_15',
#  'MAP3K5_p-PDPK1_30',
#  'MAP3K5_p-PDPK1_5',
#  'MAP3K5_p-PDPK1_60',
#  'MAP3K5_p-SMAD1-5_15',
#  'MAP3K5_p-SMAD1-5_30',
#  'MAP3K5_p-SMAD1-5_5',
#  'MAP3K5_p-SMAD2-3_0',
#  'MAP3K5_p-SMAD2-3_15',
#  'MAP3K5_p-SMAD2-3_30',
#  'MAP3K5_p-SMAD2-3_5',
#  'MAP3K5_p-SMAD2-3_60',
#  'MAP3K5_p-STAT1_0',
#  'MAP3K5_p-STAT1_15',
#  'MAP3K5_p-STAT1_30',
#  'MAP3K5_p-STAT1_5',
#  'MAP3K5_p-STAT1_60',
#  'MAP3K5_p-p38_30',
#  'MAP3K5_p-p70S6K_0',
#  'MAP3K5_p-p70S6K_30',
#  'MAP3K5_p-p70S6K_60',
#  'MAP3K5_p-p90RSK_5',
#  'MAP3K5_p-p90RSK_60',
#  'MAP8_p-JNK_15',
#  'MAP8_p-MAPKAPK2_15',
#  'MAP8_p-PDPK1_0',
#  'MAP8_p-PDPK1_30',
#  'MAP8_p-PDPK1_5',
#  'MAP8_p-PDPK1_60',
#  'MAP8_p-SMAD2-3_0',
#  'MAP8_p-SMAD2-3_15',
#  'MAP8_p-SMAD2-3_30',
#  'MAP8_p-STAT1_15',
#  'MAP8_p-STAT3_15',
#  'MAP8_p-STAT3_5',
#  'MAP8_p-STAT5_0',
#  'MAP8_p-STAT5_30',
#  'MAP8_p-STAT5_5',
#  'MAP8_p-STAT5_60',
#  'MAP8_p-p38_30',
#  'MAP8_p-p38_5',
#  'MAP8_p-p70S6K_0',
#  'MAP8_p-p70S6K_30',
#  'MAP8_p-p70S6K_60',
#  'MAPK14_p-ERK1-2_15',
#  'MAPK14_p-ERK1-2_5',
#  'MAPK14_p-ERK1-2_60',
#  'MAPK14_p-STAT5_5',
#  'MAPK14_p-p90RSK_15',
#  'MAPK14_p-p90RSK_5',
#  'MAPK14_p-p90RSK_60',
#  'MAPK1_p-AMPKalpha_15',
#  'MAPK1_p-ERK1-2_0',
#  'MAPK1_p-JNK_0',
#  'MAPK1_p-JNK_30',
#  'MAPK1_p-JNK_60',
#  'MAPK1_p-MAPKAPK2_30',
#  'MAPK1_p-MAPKAPK2_5',
#  'MAPK1_p-MAPKAPK2_60',
#  'MAPK1_p-MKK3-6_60',
#  'MAPK1_p-SMAD2-3_5',
#  'MAPK1_p-STAT1_15',
#  'MAPK1_p-STAT1_30',
#  'MAPK1_p-STAT1_60',
#  'MAPK1_p-STAT5_5',
#  'MAPK1_p-p38_0',
#  'MAPK1_p-p38_15',
#  'MAPK1_p-p38_30',
#  'MAPK1_p-p38_5',
#  'MAPK1_p-p38_60',
#  'MAPK1_p-p70S6K_15',
#  'MAPK1_p-p90RSK_15',
#  'MAPK1_p-p90RSK_5',
#  'PDPK1_p-BTK_0',
#  'PDPK1_p-BTK_15',
#  'PDPK1_p-BTK_30',
#  'PDPK1_p-BTK_5',
#  'PDPK1_p-BTK_60',
#  'PDPK1_p-FAK_30',
#  'PDPK1_p-MAPKAPK2_0',
#  'PDPK1_p-MAPKAPK2_15',
#  'PDPK1_p-MAPKAPK2_30',
#  'PDPK1_p-MAPKAPK2_5',
#  'PDPK1_p-S6_0',
#  'PDPK1_p-S6_15',
#  'PDPK1_p-S6_30',
#  'PDPK1_p-S6_5',
#  'PDPK1_p-S6_60',
#  'PDPK1_p-SHP2_15',
#  'PDPK1_p-SHP2_5',
#  'PIK3CA_p-GSK3-Beta_0',
#  'PIK3CA_p-GSK3-Beta_30',
#  'PIK3CA_p-GSK3-Beta_60',
#  'PIK3CA_p-JNK_0',
#  'PIK3CA_p-MKK3-6_0',
#  'PIK3CA_p-MKK3-6_15',
#  'PIK3CA_p-MKK3-6_30',
#  'PIK3CA_p-MKK3-6_5',
#  'PIK3CA_p-MKK3-6_60',
#  'PIK3CA_p-SMAD1-5_0',
#  'PIK3CA_p-SMAD1-5_15',
#  'PIK3CA_p-SMAD1-5_30',
#  'PIK3CA_p-SMAD1-5_5',
#  'PIK3CA_p-SMAD1-5_60',
#  'PIK3CA_p-SMAD2-3_0',
#  'PIK3CA_p-STAT1_0',
#  'PIK3CA_p-p38_0',
#  'PIK3CA_p-p38_15',
#  'PIK3CA_p-p38_30',
#  'PIK3CA_p-p38_5',
#  'PIK3CA_p-p90RSK_60',
#  'PTPN11_p-JNK_0',
#  'PTPN11_p-JNK_15',
#  'PTPN11_p-JNK_30',
#  'PTPN11_p-JNK_5',
#  'PTPN11_p-JNK_60',
#  'PTPN11_p-MARCKS_15',
#  'PTPN11_p-MARCKS_60',
#  'PTPN11_p-MKK3-6_5',
#  'PTPN11_p-p90RSK_15',
#  'PTPN11_p-p90RSK_60',
#  'RPS6KA1_E-cadherin_30',
#  'RPS6KA1_E-cadherin_5',
#  'RPS6KA1_p-ERK1-2_5',
#  'RPS6KA1_p-FAK_15',
#  'RPS6KA1_p-MEK1-2_15',
#  'RPS6KA1_p-MEK1-2_30',
#  'RPS6KA1_p-MEK1-2_5',
#  'RPS6KA1_p-MKK3_15',
#  'RPS6KA1_p-PDPK1_0',
#  'RPS6KA1_p-PDPK1_5',
#  'RPS6KA1_p-PDPK1_60',
#  'RPS6KA1_p-PLCg2_15',
#  'RPS6KA1_p-SHP2_0',
#  'RPS6KA1_p-SHP2_30',
#  'RPS6KA1_p-SHP2_5',
#  'RPS6KA1_p-SHP2_60',
#  'RPS6KA1_p-SMAD2-3_30',
#  'RPS6KA1_p-SMAD2-3_5',
#  'RPS6KA1_p-SMAD2-3_60',
#  'RPS6KA1_p-STAT1_15',
#  'RPS6KA1_p-STAT5_0',
#  'RPS6KA1_p-STAT5_15',
#  'RPS6KA1_p-STAT5_30',
#  'RPS6KA1_p-STAT5_5',
#  'RPS6KA1_p-STAT5_60',
#  'RPS6KA1_p-mTOR_15',
#  'RPS6KB1_p-ERK1-2_15',
#  'RPS6KB1_p-S6_5',
#  'RPS6KB1_p-STAT5_60',
#  'RPS6KB1_p-p70S6K_15',
#  'RPS6KB1_p-p70S6K_30',
#  'RPS6KB1_p-p70S6K_60',
#  'RPS6KB1_p-p90RSK_15',
#  'RPS6KB1_p-p90RSK_30',
#  'RPS6KB1_p-p90RSK_60',
#  'SRC_p-JNK_0',
#  'SRC_p-JNK_15',
#  'SRC_p-JNK_30',
#  'SRC_p-JNK_5',
#  'SRC_p-SMAD1-5_0',
#  'SRC_p-SMAD1-5_15',
#  'SRC_p-SMAD1-5_30',
#  'SRC_p-SMAD1-5_5',
#  'SRC_p-SMAD1-5_60'}

# %%
hits_bp.intersection(hits_dremi).difference(hits_sp)
# Out:
# {'AKT1_Beta-catenin_30',
#  'AKT1_Beta-catenin_5',
#  'BRAF_p-S6_0',
#  'KRAS_p-S6_15',
#  'MAP2K1_Beta-catenin_0',
#  'MAP2K1_Beta-catenin_5',
#  'MAP2K1_p-MARCKS_5',
#  'MAP2K1_p-MKK3-6_0',
#  'MAP2K1_p-MKK3-6_60',
#  'MAP2K1_p-p90RSK_15',
#  'RPS6KB1_p-S6_30'}

# %% [markdown]
# ## Make a table of the hits and save it

# %%
hit_dict = dict()

hit_dict['all_hits'] = list(set(list(hits_sp)+ list(hits_dremi)+ list(hits_bp)))
hit_dict['is_bp'] = [h in hits_bp for h in hit_dict['all_hits'] ]
hit_dict['is_sp'] = [h in hits_sp for h in hit_dict['all_hits'] ]
hit_dict['is_dremi'] = [h in hits_dremi for h in hit_dict['all_hits'] ]


hit_tab = pd.DataFrame.from_dict(hit_dict)
#hit_tab = hit_tab.set_index('all_hits')

hit_tab = hit_tab.sort_values(by=['is_bp','is_dremi', 'is_sp'],ascending=False)

hit_tab.to_csv(os.path.join(out_folder,'20160429_readout_comparison_vsemptygfp_woCC.csv'),index=False)
